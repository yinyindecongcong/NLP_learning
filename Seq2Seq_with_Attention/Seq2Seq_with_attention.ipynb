# %%
import tensorflow as tf
import numpy as np
# Out:
# D:\Anaconda\lib\site-packages\h5py\__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# ### 定义rnn解码部分

# %%
def rnn_decoder_with_attention(decoder_inputs, initial_state, cell, attention_states, batch_size):
    '''
    rnn解码过程——
      对decoder_inputs中的每个input:
        1.计算attention: context_vector = softmax(query * key) * value
        2.rnn cell运行: output, state = cell(input, state, context_vector)
    输入——
      decoder_inputs: 一个2D-tensor的列表，每个tensor的shape=[batch_size, input_size]
      initial_state: cell的初始状态，此处使用的是由encoder最后一个输出计算的结果，shape=[batch_size, cell.state_size]，
                     此处state_size=hidden_size * 2
      cell: 使用的rnn_cell，此处使用带attention的双向gru cell
      loop_function: 测试的时候使用的，TODO
      attention_states: encoder的outputs，是一个3D-tensor，shape=[batch_size, sentence_len, hidden_size * 2]
    '''
    #定义一些量
    state = initial_state
    attention_states_origin = attention_states #[batch_size, sentence_len, state_size]
    _, sentence_len, state_size = attention_states.get_shape().as_list()
    outputs = []
    for idx in range(len(decoder_inputs)):
        #训练时把上一轮的state作为输入
        #1.计算attention
#         Q = tf.get_variable('Q', shape=[state_size, state_size], initializer=tf.random_normal_initializer(stddev=0.1))
#         K = tf.get_variable('K', shape=[state_size, state_size], initializer=tf.random_normal_initializer(stddev=0.1))
#         V = tf.get_variable('V', shape=[state_size, state_size], initializer=tf.random_normal_initializer(stddev=0.1))
        query = tf.reshape(state, (-1, 1, state_size)) #[batch_size, 1, state_size]
        key = attention_states #[batch_size, state_size, sentence_len]
        attention_logits = [tf.matmul(query[i], tf.transpose(key[i])) for i in range(batch_size)] #batch中的每个query与输入的key计算匹配程度
        attention_logits = tf.random_normal([batch_size, sentence_len])
        attention_logits = tf.reshape(attention_logits, [batch_size, sentence_len]) #[batch_size, sentence_len]
        p_attention = tf.nn.softmax(attention_logits) #计算概率，[batch_size, sentence_len]
        p_attention = tf.reshape(p_attention, [batch_size, sentence_len, 1])
        context_vector = tf.multiply(attention_states_origin, p_attention) #按位乘，在第三维自动扩展，[batch_size, sentence_len, state_size]
        context_vector = tf.reduce_sum(context_vector, axis=1) #[batch_size, state_size]
        #2.运行cell
        output, state = cell(decoder_inputs[idx], state, context_vector)
        outputs.append(output)
    return outputs, state

# %% [markdown]
# ### 定义seq2seq

# %%
class Seq2Seq_with_attention:
    def __init__(self, num_classes, batch_size, sentence_len, 
                 embed_size, vocab_size, hidden_size, learning_rate, 
                 decay_steps, decay_rate, is_training=True, decode_sent_length=5):
        #初始化hyperparameter
        self.num_classes = num_classes
        self.batch_size = batch_size
        self.sentence_len = sentence_len
        self.embed_size = embed_size
        self.vocab_size = vocab_size
        self.hidden_size = hidden_size
        self.learning_rate = learning_rate
        self.is_training = is_training
        self.decode_sent_length = decode_sent_length
        self.initializer = tf.random_normal_initializer(stddev=0.1)
        
        #输入
        self.input_x = tf.placeholder(tf.int32, [None, self.sentence_len], 'input_x')
        self.decoder_input = tf.placeholder(tf.int32, [None, self.decode_sent_length], 'decoder_input') #
        self.input_y = tf.placeholder(tf.int32, [None, self.decode_sent_length], 'input_y')
#         self.dropout_keep_prob = tf.placeholder(tf.float32, name='dropout_keep_prob')
        
        #epoch信息
        self.global_step = tf.Variable(0, trainable=False, dtype=tf.int32, name='global_step')
        self.epoch_step = tf.Variable(0, trainable=False, dtype=tf.int32, name='epoch_step')
        self.epoch_increment = tf.assign(self.epoch_step, tf.add(self.epoch_step, tf.constant(1)))
        self.decay_steps, self.decay_rate = decay_steps, decay_rate
        
        self.init_weight()
        self.logits = self.inference()
        
        self.predictions = tf.argmax(self.logits, axis=2,name='prediction')
        self.loss_val = self.loss()
        self.train_op = self.train()
    
    def inference(self):
        '''
        embedding --> encode using gru --> decode using gru with attention --> linear classifier
        '''
        #1. embedding
        self.embedding_sentence = tf.nn.embedding_lookup(self.Embedding, self.input_x) #[batch_size, sentence_len, embed_size]
        #2. encoder with GRU
        h_t_list_forward = self.gru_cell_run(self.embedding_sentence, self.gru_cell) #list,每个元素为[batch_size, hidden_size]
        h_t_list_backward = self.gru_cell_run(self.embedding_sentence, self.gru_cell, forward=False) 
        encoder_outputs_list = [tf.concat((f,b), axis=1) for f, b in zip(h_t_list_forward, h_t_list_backward)]
        #list,每个元素为[batch_size, hidden_size * 2]
        encoder_outputs = tf.stack(encoder_outputs_list, axis=1) #[batch_size, sentence_len, hidden_size * 2]
        #3. decode using GRU with attention
        #a. 初始化decoder的第一个状态
        initial_state = tf.tanh(tf.matmul(h_t_list_backward[0], self.W_init_state) + self.b_init_state) #[batch_size, hidden_size * 2]
        #b. embedding decoder input
        embedding_decoder_input = tf.nn.embedding_lookup(self.Embedding_label, self.decoder_input) #[batch_size, deccode_len, embed_size]
        embedding_decoder_input_split = tf.split(embedding_decoder_input, self.decode_sent_length, axis=1)
        embedding_decoder_input_list = [tf.squeeze(x,axis=1) for x in embedding_decoder_input_split]#list,每个元素为[batch_size, embed_size]
        #c. run cell with attention
        cell = self.gru_cell_decode
        attention_states = encoder_outputs
        loop_function = None
        outputs, state = rnn_decoder_with_attention(embedding_decoder_input_list, initial_state, 
                                                    cell, attention_states, self.batch_size)
        # outputs: list，每个元素为[batch_size, output_size]，这里output_size = hidden_size*2(只用了一个gru，注意维度)
        decoder_output = tf.stack(outputs, axis=1) #[batch_size, decode_len, hidden_size * 2]
        decoder_output = tf.reshape(decoder_output, [-1, self.hidden_size * 2]) #[batch_size * decode_len, hidden_size * 2]
        logits = tf.matmul(decoder_output, self.W_logits) + self.b_logits   #[batch_size * decode_len, num_classes]
        logits = tf.reshape(logits, [self.batch_size, self.decode_sent_length, self.num_classes])# [batch_size, decode_len, num_classes]
        return logits
        
    def loss(self, l2_lambda=0.001):
        losses = tf.nn.sparse_softmax_cross_entropy_with_logits(labels=self.input_y, logits=self.logits)#[batch_size, decode_sen_len]
        loss1 = tf.reduce_mean(tf.reduce_sum(losses, axis=1))
        l2_loss = tf.add_n([tf.nn.l2_loss(t) for t in tf.trainable_variables()]) * l2_lambda
        return loss1 + l2_loss
        
    def train(self):
        learning_rate = tf.train.exponential_decay(self.learning_rate,self.global_step,self.decay_steps,self.decay_rate,True)
        train_op = tf.contrib.layers.optimize_loss(self.loss_val, self.global_step,learning_rate, 'Adam')
        return train_op
    
    def gru_cell(self, X_t, h_t_minus_1):
        #reset gate
        r_t = tf.sigmoid(tf.matmul(h_t_minus_1, self.W_r) + tf.matmul(X_t, self.U_r) + self.b_r) #[batch_size, hidden_size]
        #生成候选h_t
        h_t_cand = tf.tanh(tf.matmul(r_t * h_t_minus_1, self.W_c) + tf.matmul(X_t, self.U_c) + self.b_c) #[batch_size, hidden_size]
        #update gate
        z_t = tf.sigmoid(tf.matmul(h_t_minus_1, self.W_z) + tf.matmul(X_t, self.U_z) + self.b_z) #[batch_size, hidden_size]
        #生成新的h_t
        h_t = (1 - z_t) * h_t_minus_1 + z_t * h_t_cand #[batch_size, hidden_size]
        return h_t
        
    def gru_cell_run(self, embedding_sentence, gru_cell, forward=True):
        '''
        input：embedding_sentence: [batch_size, sentence_len, embed_size]
        output：list of h_t,每个h_t的shape: [batch_size, hidden_size]
        '''
        embedding_sentence_split = tf.split(embedding_sentence, self.sentence_len, axis=1) #a list, each element is [batch_size,1,embed_size]
        embedding_sentence_list = [tf.squeeze(x, axis=1) for x in embedding_sentence_split] #a list, each element is [batch_size,embed_size]
        h_t = tf.ones((self.batch_size, self.hidden_size)) #初始化
        h_t_list = []
        if forward == False:
            embedding_sentence_list.reverse()
        for i in range(self.sentence_len):
            h_t = gru_cell(embedding_sentence_list[i], h_t)
            h_t_list.append(h_t)
        if forward == False:
            h_t_list.reverse()
        return h_t_list
    
    def gru_cell_decode(self, X_t, h_t_minus_1, context_vector):
        #reset gate
        r_t = tf.sigmoid(tf.matmul(h_t_minus_1, self.W_r_decode) + tf.matmul(X_t, self.U_r_decode) + self.b_r_decode) #[batch_size, hidden_size * 2]
        #生成候选h_t
        h_t_cand = tf.tanh(tf.matmul(r_t * h_t_minus_1, self.W_c_decode) + tf.matmul(X_t, self.U_c_decode)+ self.b_c_decode) #[batch_size, hidden_size * 2]
        #update gate
        z_t = tf.sigmoid(tf.matmul(h_t_minus_1, self.W_z_decode) + tf.matmul(X_t, self.U_z_decode) + self.b_z_decode) #[batch_size, hidden_size * 2]
        #生成新的h_t
        h_t = (1 - z_t) * h_t_minus_1 + z_t * h_t_cand #[batch_size, hidden_size * 2]
        #print(h_t.get_shape())
        #print(h_t_minus_1.get_shape())
        return h_t, h_t
        #return h_t_minus_1, h_t_minus_1
        
        
    def init_weight(self):
        '''定义所有weights'''
        #单词的embedding和label的embedding，其中label的embedding负责将decoder_input做embedding
        self.Embedding = tf.get_variable('Embedding', [self.vocab_size, self.embed_size], tf.float32, self.initializer)
        self.Embedding_label = tf.get_variable('Embedding_label', [self.num_classes, self.embed_size], tf.float32, self.initializer)
        #将encoder的第一个output映射为decoder的初始state
        self.W_init_state = tf.get_variable('W_init_state', [self.hidden_size, self.hidden_size * 2], tf.float32, self.initializer)
        self.b_init_state = tf.get_variable('b_init_state', [self.hidden_size * 2], tf.float32, self.initializer)
        #将decoder的outputs映射为logits
        self.W_logits = tf.get_variable('W_logits', [self.hidden_size * 2, self.num_classes], tf.float32, self.initializer)
        self.b_logits = tf.get_variable('b_logits', [self.num_classes], tf.float32, self.initializer)
        #encoder的gru门所需参数
            #reset gate
        self.W_r = tf.get_variable('W_r', [self.hidden_size, self.hidden_size], tf.float32, self.initializer)
        self.U_r = tf.get_variable('U_r', [self.embed_size, self.hidden_size], tf.float32, self.initializer)
        self.b_r = tf.get_variable('b_r', [self.hidden_size], tf.float32, self.initializer)
            #生成候选h_t
        self.W_c = tf.get_variable('W_c', [self.hidden_size, self.hidden_size], tf.float32, self.initializer)
        self.U_c = tf.get_variable('U_c', [self.embed_size, self.hidden_size], tf.float32, self.initializer)
        self.b_c = tf.get_variable('b_c', [self.hidden_size], tf.float32, self.initializer)
            #update gate
        self.W_z = tf.get_variable('W_z', [self.hidden_size, self.hidden_size], tf.float32, self.initializer)
        self.U_z = tf.get_variable('U_z', [self.embed_size, self.hidden_size], tf.float32, self.initializer)
        self.b_z = tf.get_variable('b_z', [self.hidden_size], tf.float32, self.initializer)
        #dncoder的gru门所需参数
            #reset gate
        self.W_r_decode = tf.get_variable('W_r_decode', [self.hidden_size * 2, self.hidden_size * 2], tf.float32, self.initializer)
        self.U_r_decode = tf.get_variable('U_r_decode', [self.embed_size, self.hidden_size * 2], tf.float32, self.initializer)
        self.C_r_decode = tf.get_variable('C_r_decode', [self.hidden_size * 2, self.hidden_size * 2], tf.float32, self.initializer)
        self.b_r_decode = tf.get_variable('b_r_decode', [self.hidden_size * 2], tf.float32, self.initializer)
            #生成候选h_t
        self.W_c_decode = tf.get_variable('W_c_decode', [self.hidden_size * 2, self.hidden_size * 2], tf.float32, self.initializer)
        self.U_c_decode = tf.get_variable('U_c_decode', [self.embed_size, self.hidden_size * 2], tf.float32, self.initializer)
        self.C_c_decode = tf.get_variable('C_c_decode', [self.hidden_size * 2, self.hidden_size * 2], tf.float32, self.initializer)
        self.b_c_decode = tf.get_variable('b_c_decode', [self.hidden_size * 2], tf.float32, self.initializer)
            #update gate
        self.W_z_decode = tf.get_variable('W_z_decode', [self.hidden_size * 2, self.hidden_size * 2], tf.float32, self.initializer)
        self.U_z_decode = tf.get_variable('U_z_decode', [self.embed_size, self.hidden_size * 2], tf.float32, self.initializer)
        self.C_z_decode = tf.get_variable('C_z_decode', [self.hidden_size * 2, self.hidden_size * 2], tf.float32, self.initializer)
        self.b_z_decode = tf.get_variable('b_z_decode', [self.hidden_size * 2], tf.float32, self.initializer)

# %% [markdown]
# #### 测试

# %%
import copy
def test():
    # below is a function test; if you use this for text classifiction, you need to tranform sentence to indices of vocabulary first. then feed data to the graph.
    num_classes = 9+2 #additional two classes:one is for _GO, another is for _END
    learning_rate = 0.0001
    batch_size = 1
    decay_steps = 1000
    decay_rate = 0.9
    sequence_length = 5
    vocab_size = 300
    embed_size = 100 #100
    hidden_size = 100
    is_training = True
    dropout_keep_prob = 1  # 0.5 #num_sentences
    decoder_sent_length=6
    l2_lambda=0.0001
    model = Seq2Seq_with_attention(num_classes, batch_size, sequence_length, 
                 embed_size, vocab_size, hidden_size, learning_rate, 
                 decay_steps, decay_rate, is_training, decoder_sent_length)
    with tf.Session() as sess:
        sess.run(tf.global_variables_initializer())
        for i in range(1500):
            #input_x = np.zeros((batch_size, sequence_length),dtype=np.int32) #[None, self.sequence_length]
            label_list=get_unique_labels()
            input_x = np.array([label_list],dtype=np.int32) #[2,3,4,5,6]
            label_list_original=copy.deepcopy(label_list)
            label_list.reverse()
            decoder_input=np.array([[0]+label_list],dtype=np.int32) #[[0,2,3,4,5,6]]
            input_y_label=np.array([label_list+[1]],dtype=np.int32) #[[2,3,4,5,6,1]]
            loss, predict, _ = sess.run([model.loss_val, model.predictions, model.train_op],
                                        feed_dict={model.input_x:input_x,model.decoder_input:decoder_input, model.input_y: input_y_label})
            print(i,"loss:", loss, "label_list_original as input x:",label_list_original,";input_y_label:", input_y_label, "prediction:", predict)
            
import random
def get_unique_labels():
    x=[2,3,4,5,6]
    random.shuffle(x)
    return x

tf.reset_default_graph()
test()
# Out:
# 0 loss: 16.829098 label_list_original as input x: [6, 3, 2, 4, 5] ;input_y_label: [[5 4 2 3 6 1]] prediction: [[ 7  3  3 10  7 10]]
# 1 loss: 16.98711 label_list_original as input x: [4, 2, 6, 5, 3] ;input_y_label: [[3 5 6 2 4 1]] prediction: [[ 7  7  3 10 10 10]]
# 2 loss: 17.034191 label_list_original as input x: [2, 6, 5, 4, 3] ;input_y_label: [[3 4 5 6 2 1]] prediction: [[ 7  3  3  3  7 10]]
# 3 loss: 17.53306 label_list_original as input x: [5, 4, 2, 3, 6] ;input_y_label: [[6 3 2 4 5 1]] prediction: [[ 7  7 10 10 10 10]]
# 4 loss: 17.095333 label_list_original as input x: [5, 2, 3, 6, 4] ;input_y_label: [[4 6 3 2 5 1]] prediction: [[ 7  3  7 10 10 10]]
# 5 loss: 16.707285 label_list_original as input x: [4, 2, 3, 6, 5] ;input_y_label: [[5 6 3 2 4 1]] prediction: [[ 7  3  3  3 10 10]]
# 6 loss: 16.595322 label_list_original as input x: [4, 2, 5, 6, 3] ;input_y_label: [[3 6 5 2 4 1]] prediction: [[ 3  3  7 10 10 10]]
# 7 loss: 16.501522 label_list_original as input x: [2, 4, 3, 5, 6] ;input_y_label: [[6 5 3 4 2 1]] prediction: [[ 3  3  3  3  3 10]]
# 8 loss: 16.722567 label_list_original as input x: [4, 2, 5, 3, 6] ;input_y_label: [[6 3 5 2 4 1]] prediction: [[ 3  3  3  3 10  3]]
# 9 loss: 16.49417 label_list_original as input x: [4, 5, 6, 2, 3] ;input_y_label: [[3 2 6 5 4 1]] prediction: [[ 3  3  3  7 10  3]]
# 10 loss: 16.271118 label_list_original as input x: [2, 6, 5, 4, 3] ;input_y_label: [[3 4 5 6 2 1]] prediction: [[ 3  3  3  3  3 10]]
# 11 loss: 16.26001 label_list_original as input x: [3, 4, 6, 2, 5] ;input_y_label: [[5 2 6 4 3 1]] prediction: [[ 3  3  3  3  3 10]]
# 12 loss: 16.838861 label_list_original as input x: [3, 5, 4, 2, 6] ;input_y_label: [[6 2 4 5 3 1]] prediction: [[3 3 4 3 3 3]]
# 13 loss: 16.391214 label_list_original as input x: [3, 4, 5, 6, 2] ;input_y_label: [[2 6 5 4 3 1]] prediction: [[3 3 3 3 3 3]]
# 14 loss: 16.560158 label_list_original as input x: [4, 3, 2, 5, 6] ;input_y_label: [[6 5 2 3 4 1]] prediction: [[3 3 3 3 3 3]]
# 15 loss: 16.067408 label_list_original as input x: [3, 6, 2, 5, 4] ;input_y_label: [[4 5 2 6 3 1]] prediction: [[3 3 3 3 4 3]]
# 16 loss: 15.757028 label_list_original as input x: [6, 2, 5, 4, 3] ;input_y_label: [[3 4 5 2 6 1]] prediction: [[3 3 3 3 3 4]]
# 17 loss: 15.401474 label_list_original as input x: [2, 6, 3, 4, 5] ;input_y_label: [[5 4 3 6 2 1]] prediction: [[3 3 3 3 3 4]]
# 18 loss: 15.266677 label_list_original as input x: [6, 2, 4, 3, 5] ;input_y_label: [[5 3 4 2 6 1]] prediction: [[3 3 3 3 2 4]]
# 19 loss: 15.860521 label_list_original as input x: [3, 6, 5, 2, 4] ;input_y_label: [[4 2 5 6 3 1]] prediction: [[3 3 3 3 4 3]]
# 20 loss: 15.875 label_list_original as input x: [3, 4, 5, 6, 2] ;input_y_label: [[2 6 5 4 3 1]] prediction: [[3 3 3 3 3 3]]
# 21 loss: 16.33028 label_list_original as input x: [4, 3, 5, 2, 6] ;input_y_label: [[6 2 5 3 4 1]] prediction: [[3 3 4 3 3 2]]
# 22 loss: 15.147836 label_list_original as input x: [2, 5, 6, 3, 4] ;input_y_label: [[4 3 6 5 2 1]] prediction: [[3 3 3 3 3 4]]
# 23 loss: 15.311556 label_list_original as input x: [3, 2, 6, 4, 5] ;input_y_label: [[5 4 6 2 3 1]] prediction: [[3 3 3 3 4 4]]
# 24 loss: 14.731251 label_list_original as input x: [2, 4, 6, 5, 3] ;input_y_label: [[3 5 6 4 2 1]] prediction: [[3 3 3 3 3 4]]
# 25 loss: 15.339251 label_list_original as input x: [4, 5, 2, 6, 3] ;input_y_label: [[3 6 2 5 4 1]] prediction: [[3 3 3 4 4 3]]
# 26 loss: 15.3494005 label_list_original as input x: [6, 4, 3, 5, 2] ;input_y_label: [[2 5 3 4 6 1]] prediction: [[3 3 3 3 2 4]]
# 27 loss: 15.10763 label_list_original as input x: [6, 5, 3, 4, 2] ;input_y_label: [[2 4 3 5 6 1]] prediction: [[3 3 3 3 3 4]]
# 28 loss: 15.002189 label_list_original as input x: [3, 6, 4, 2, 5] ;input_y_label: [[5 2 4 6 3 1]] prediction: [[3 3 3 3 3 4]]
# 29 loss: 15.764507 label_list_original as input x: [5, 4, 3, 2, 6] ;input_y_label: [[6 2 3 4 5 1]] prediction: [[3 3 4 3 2 3]]
# 30 loss: 14.962769 label_list_original as input x: [6, 3, 5, 4, 2] ;input_y_label: [[2 4 5 3 6 1]] prediction: [[3 3 3 3 3 4]]
# 31 loss: 15.414686 label_list_original as input x: [5, 3, 4, 2, 6] ;input_y_label: [[6 2 4 3 5 1]] prediction: [[3 3 4 3 6 3]]
# 32 loss: 15.049538 label_list_original as input x: [3, 5, 2, 6, 4] ;input_y_label: [[4 6 2 5 3 1]] prediction: [[3 3 3 4 4 3]]
# 33 loss: 14.991423 label_list_original as input x: [5, 3, 2, 6, 4] ;input_y_label: [[4 6 2 3 5 1]] prediction: [[3 3 3 4 6 4]]
# 34 loss: 14.739994 label_list_original as input x: [6, 5, 4, 3, 2] ;input_y_label: [[2 3 4 5 6 1]] prediction: [[3 3 3 2 2 4]]
# 35 loss: 14.422612 label_list_original as input x: [6, 5, 3, 4, 2] ;input_y_label: [[2 4 3 5 6 1]] prediction: [[3 3 3 6 3 4]]
# 36 loss: 14.962346 label_list_original as input x: [4, 3, 2, 5, 6] ;input_y_label: [[6 5 2 3 4 1]] prediction: [[3 3 3 4 3 2]]
# 37 loss: 14.086472 label_list_original as input x: [2, 6, 4, 5, 3] ;input_y_label: [[3 5 4 6 2 1]] prediction: [[3 3 3 3 3 4]]
# 38 loss: 14.384811 label_list_original as input x: [4, 5, 2, 6, 3] ;input_y_label: [[3 6 2 5 4 1]] prediction: [[3 3 5 4 4 3]]
# 39 loss: 14.782303 label_list_original as input x: [3, 4, 5, 2, 6] ;input_y_label: [[6 2 5 4 3 1]] prediction: [[3 3 4 3 3 2]]
# 40 loss: 14.573597 label_list_original as input x: [5, 3, 2, 4, 6] ;input_y_label: [[6 4 2 3 5 1]] prediction: [[3 3 3 4 6 4]]
# 41 loss: 14.111041 label_list_original as input x: [6, 5, 4, 2, 3] ;input_y_label: [[3 2 4 5 6 1]] prediction: [[3 3 3 2 2 4]]
# 42 loss: 13.964411 label_list_original as input x: [4, 5, 6, 2, 3] ;input_y_label: [[3 2 6 5 4 1]] prediction: [[3 3 3 4 4 3]]
# 43 loss: 14.396879 label_list_original as input x: [4, 5, 2, 3, 6] ;input_y_label: [[6 3 2 5 4 1]] prediction: [[3 3 5 4 4 2]]
# 44 loss: 13.919312 label_list_original as input x: [5, 2, 6, 4, 3] ;input_y_label: [[3 4 6 2 5 1]] prediction: [[3 3 3 5 4 4]]
# 45 loss: 13.752976 label_list_original as input x: [6, 5, 4, 2, 3] ;input_y_label: [[3 2 4 5 6 1]] prediction: [[3 3 3 2 2 4]]
# 46 loss: 14.058548 label_list_original as input x: [3, 2, 5, 4, 6] ;input_y_label: [[6 4 5 2 3 1]] prediction: [[3 3 3 3 4 6]]
# 47 loss: 13.400265 label_list_original as input x: [2, 6, 3, 4, 5] ;input_y_label: [[5 4 3 6 2 1]] prediction: [[3 3 3 2 5 4]]
# 48 loss: 13.901802 label_list_original as input x: [3, 5, 4, 6, 2] ;input_y_label: [[2 6 4 5 3 1]] prediction: [[3 3 4 2 4 6]]
# 49 loss: 13.032631 label_list_original as input x: [2, 4, 5, 6, 3] ;input_y_label: [[3 6 5 4 2 1]] prediction: [[3 3 5 4 2 4]]
# 50 loss: 13.430856 label_list_original as input x: [4, 2, 3, 6, 5] ;input_y_label: [[5 6 3 2 4 1]] prediction: [[3 3 3 5 4 2]]
# 51 loss: 13.134746 label_list_original as input x: [6, 5, 2, 4, 3] ;input_y_label: [[3 4 2 5 6 1]] prediction: [[3 3 2 2 2 4]]
# 52 loss: 13.152313 label_list_original as input x: [6, 5, 3, 4, 2] ;input_y_label: [[2 4 3 5 6 1]] prediction: [[3 3 2 2 2 1]]
# 53 loss: 13.522114 label_list_original as input x: [4, 5, 3, 6, 2] ;input_y_label: [[2 6 3 5 4 1]] prediction: [[3 3 4 5 4 2]]
# 54 loss: 13.523863 label_list_original as input x: [3, 2, 5, 4, 6] ;input_y_label: [[6 4 5 2 3 1]] prediction: [[3 4 2 2 4 1]]
# 55 loss: 13.13609 label_list_original as input x: [6, 3, 5, 2, 4] ;input_y_label: [[4 2 5 3 6 1]] prediction: [[3 3 2 2 6 1]]
# 56 loss: 13.126644 label_list_original as input x: [6, 4, 3, 2, 5] ;input_y_label: [[5 2 3 4 6 1]] prediction: [[3 3 3 2 2 1]]
# 57 loss: 12.81971 label_list_original as input x: [2, 6, 5, 4, 3] ;input_y_label: [[3 4 5 6 2 1]] prediction: [[3 3 2 2 4 1]]
# 58 loss: 12.375758 label_list_original as input x: [2, 4, 5, 6, 3] ;input_y_label: [[3 6 5 4 2 1]] prediction: [[3 3 5 4 2 1]]
# 59 loss: 13.338201 label_list_original as input x: [3, 4, 5, 2, 6] ;input_y_label: [[6 2 5 4 3 1]] prediction: [[3 4 4 4 2 1]]
# 60 loss: 13.103058 label_list_original as input x: [3, 5, 2, 4, 6] ;input_y_label: [[6 4 2 5 3 1]] prediction: [[3 4 2 4 4 1]]
# 61 loss: 13.051577 label_list_original as input x: [3, 2, 5, 4, 6] ;input_y_label: [[6 4 5 2 3 1]] prediction: [[3 4 2 2 4 1]]
# 62 loss: 12.864614 label_list_original as input x: [5, 4, 2, 3, 6] ;input_y_label: [[6 3 2 4 5 1]] prediction: [[3 3 5 4 2 1]]
# 63 loss: 12.743652 label_list_original as input x: [6, 4, 3, 2, 5] ;input_y_label: [[5 2 3 4 6 1]] prediction: [[3 3 4 2 2 1]]
# 64 loss: 12.484765 label_list_original as input x: [5, 6, 3, 4, 2] ;input_y_label: [[2 4 3 6 5 1]] prediction: [[3 3 2 2 5 1]]
# 65 loss: 12.062838 label_list_original as input x: [4, 2, 5, 6, 3] ;input_y_label: [[3 6 5 2 4 1]] prediction: [[3 3 5 4 4 1]]
# 66 loss: 12.5532675 label_list_original as input x: [2, 6, 3, 5, 4] ;input_y_label: [[4 5 3 6 2 1]] prediction: [[3 3 2 2 1 1]]
# 67 loss: 12.508545 label_list_original as input x: [6, 3, 4, 5, 2] ;input_y_label: [[2 5 4 3 6 1]] prediction: [[3 3 3 2 2 1]]
# 68 loss: 12.189925 label_list_original as input x: [2, 6, 5, 4, 3] ;input_y_label: [[3 4 5 6 2 1]] prediction: [[3 3 2 2 1 1]]
# 69 loss: 12.321189 label_list_original as input x: [2, 3, 4, 5, 6] ;input_y_label: [[6 5 4 3 2 1]] prediction: [[3 4 4 2 1 1]]
# 70 loss: 12.471143 label_list_original as input x: [3, 6, 2, 5, 4] ;input_y_label: [[4 5 2 6 3 1]] prediction: [[3 3 2 4 1 1]]
# 71 loss: 12.257225 label_list_original as input x: [4, 5, 2, 3, 6] ;input_y_label: [[6 3 2 5 4 1]] prediction: [[3 4 5 4 1 1]]
# 72 loss: 12.233961 label_list_original as input x: [2, 3, 5, 4, 6] ;input_y_label: [[6 4 5 3 2 1]] prediction: [[3 4 2 2 1 1]]
# 73 loss: 12.349782 label_list_original as input x: [3, 5, 4, 2, 6] ;input_y_label: [[6 2 4 5 3 1]] prediction: [[3 4 4 2 1 1]]
# 74 loss: 12.079062 label_list_original as input x: [5, 4, 2, 3, 6] ;input_y_label: [[6 3 2 4 5 1]] prediction: [[3 4 5 4 1 1]]
# 75 loss: 12.031257 label_list_original as input x: [4, 6, 5, 3, 2] ;input_y_label: [[2 3 5 6 4 1]] prediction: [[3 3 5 2 1 1]]
# 76 loss: 12.218001 label_list_original as input x: [3, 6, 5, 4, 2] ;input_y_label: [[2 4 5 6 3 1]] prediction: [[3 4 2 2 1 1]]
# 77 loss: 11.449773 label_list_original as input x: [2, 4, 6, 5, 3] ;input_y_label: [[3 5 6 4 2 1]] prediction: [[3 3 3 4 1 1]]
# 78 loss: 11.932458 label_list_original as input x: [5, 4, 6, 3, 2] ;input_y_label: [[2 3 6 4 5 1]] prediction: [[3 4 5 5 1 1]]
# 79 loss: 11.661841 label_list_original as input x: [4, 6, 2, 5, 3] ;input_y_label: [[3 5 2 6 4 1]] prediction: [[3 5 2 4 1 1]]
# 80 loss: 12.117471 label_list_original as input x: [3, 6, 4, 2, 5] ;input_y_label: [[5 2 4 6 3 1]] prediction: [[3 3 4 2 1 1]]
# 81 loss: 11.771804 label_list_original as input x: [6, 3, 5, 4, 2] ;input_y_label: [[2 4 5 3 6 1]] prediction: [[3 4 2 2 1 1]]
# 82 loss: 11.5286665 label_list_original as input x: [3, 2, 4, 5, 6] ;input_y_label: [[6 5 4 2 3 1]] prediction: [[3 4 4 2 1 1]]
# 83 loss: 11.598341 label_list_original as input x: [5, 4, 2, 3, 6] ;input_y_label: [[6 3 2 4 5 1]] prediction: [[3 4 5 4 1 1]]
# 84 loss: 11.546684 label_list_original as input x: [2, 3, 5, 4, 6] ;input_y_label: [[6 4 5 3 2 1]] prediction: [[3 5 5 4 1 1]]
# 85 loss: 11.501567 label_list_original as input x: [6, 5, 3, 4, 2] ;input_y_label: [[2 4 3 5 6 1]] prediction: [[3 4 2 5 1 1]]
# 86 loss: 11.468538 label_list_original as input x: [3, 4, 2, 6, 5] ;input_y_label: [[5 6 2 4 3 1]] prediction: [[3 3 4 4 1 1]]
# 87 loss: 11.7210655 label_list_original as input x: [3, 6, 2, 4, 5] ;input_y_label: [[5 4 2 6 3 1]] prediction: [[3 3 2 4 1 1]]
# 88 loss: 11.800996 label_list_original as input x: [2, 3, 6, 4, 5] ;input_y_label: [[5 4 6 3 2 1]] prediction: [[3 3 3 4 1 1]]
# 89 loss: 11.712746 label_list_original as input x: [5, 2, 6, 4, 3] ;input_y_label: [[3 4 6 2 5 1]] prediction: [[3 6 5 5 1 1]]
# 90 loss: 11.558261 label_list_original as input x: [3, 6, 5, 2, 4] ;input_y_label: [[4 2 5 6 3 1]] prediction: [[6 5 4 4 1 1]]
# 91 loss: 11.552445 label_list_original as input x: [3, 5, 6, 2, 4] ;input_y_label: [[4 2 6 5 3 1]] prediction: [[6 6 4 4 1 1]]
# 92 loss: 11.29401 label_list_original as input x: [6, 2, 3, 4, 5] ;input_y_label: [[5 4 3 2 6 1]] prediction: [[3 3 2 2 1 1]]
# 93 loss: 11.330149 label_list_original as input x: [3, 4, 6, 2, 5] ;input_y_label: [[5 2 6 4 3 1]] prediction: [[5 6 4 4 1 1]]
# 94 loss: 11.104612 label_list_original as input x: [2, 3, 5, 4, 6] ;input_y_label: [[6 4 5 3 2 1]] prediction: [[6 4 2 3 1 1]]
# 95 loss: 11.433014 label_list_original as input x: [6, 4, 3, 2, 5] ;input_y_label: [[5 2 3 4 6 1]] prediction: [[5 6 4 2 1 1]]
# 96 loss: 11.220934 label_list_original as input x: [2, 5, 3, 4, 6] ;input_y_label: [[6 4 3 5 2 1]] prediction: [[6 4 2 2 1 1]]
# 97 loss: 11.316231 label_list_original as input x: [6, 4, 5, 2, 3] ;input_y_label: [[3 2 5 4 6 1]] prediction: [[5 6 4 3 1 1]]
# 98 loss: 11.159313 label_list_original as input x: [6, 4, 2, 3, 5] ;input_y_label: [[5 3 2 4 6 1]] prediction: [[5 6 2 3 1 1]]
# 99 loss: 11.195459 label_list_original as input x: [3, 6, 4, 5, 2] ;input_y_label: [[2 5 4 6 3 1]] prediction: [[5 4 4 3 1 1]]
# 100 loss: 11.023655 label_list_original as input x: [3, 4, 5, 6, 2] ;input_y_label: [[2 6 5 4 3 1]] prediction: [[5 4 4 3 1 1]]
# 101 loss: 11.333114 label_list_original as input x: [6, 5, 4, 3, 2] ;input_y_label: [[2 3 4 5 6 1]] prediction: [[5 4 2 2 1 1]]
# 102 loss: 10.997601 label_list_original as input x: [3, 6, 4, 5, 2] ;input_y_label: [[2 5 4 6 3 1]] prediction: [[5 4 4 3 1 1]]
# 103 loss: 11.406214 label_list_original as input x: [5, 3, 2, 6, 4] ;input_y_label: [[4 6 2 3 5 1]] prediction: [[5 2 4 4 1 1]]
# 104 loss: 11.393845 label_list_original as input x: [2, 5, 4, 3, 6] ;input_y_label: [[6 3 4 5 2 1]] prediction: [[5 5 5 2 1 1]]
# 105 loss: 11.154627 label_list_original as input x: [6, 5, 2, 4, 3] ;input_y_label: [[3 4 2 5 6 1]] prediction: [[5 5 2 4 1 1]]
# 106 loss: 10.929858 label_list_original as input x: [3, 5, 6, 4, 2] ;input_y_label: [[2 4 6 5 3 1]] prediction: [[5 4 2 4 1 1]]
# 107 loss: 10.700422 label_list_original as input x: [3, 4, 5, 6, 2] ;input_y_label: [[2 6 5 4 3 1]] prediction: [[5 4 4 4 1 1]]
# 108 loss: 10.562973 label_list_original as input x: [3, 6, 5, 4, 2] ;input_y_label: [[2 4 5 6 3 1]] prediction: [[5 4 2 3 1 1]]
# 109 loss: 11.259315 label_list_original as input x: [4, 5, 2, 6, 3] ;input_y_label: [[3 6 2 5 4 1]] prediction: [[5 5 5 4 1 1]]
# 110 loss: 10.641872 label_list_original as input x: [6, 3, 5, 2, 4] ;input_y_label: [[4 2 5 3 6 1]] prediction: [[2 2 4 3 1 1]]
# 111 loss: 11.096195 label_list_original as input x: [2, 3, 6, 5, 4] ;input_y_label: [[4 5 6 3 2 1]] prediction: [[5 5 6 3 1 1]]
# 112 loss: 10.689138 label_list_original as input x: [3, 6, 2, 5, 4] ;input_y_label: [[4 5 2 6 3 1]] prediction: [[2 2 6 3 1 1]]
# 113 loss: 11.1011 label_list_original as input x: [5, 6, 4, 3, 2] ;input_y_label: [[2 3 4 6 5 1]] prediction: [[2 4 5 6 1 1]]
# 114 loss: 11.134541 label_list_original as input x: [4, 6, 2, 5, 3] ;input_y_label: [[3 5 2 6 4 1]] prediction: [[2 5 6 6 1 1]]
# 115 loss: 10.326325 label_list_original as input x: [3, 4, 5, 6, 2] ;input_y_label: [[2 6 5 4 3 1]] prediction: [[2 4 4 3 1 1]]
# 116 loss: 11.459304 label_list_original as input x: [5, 2, 6, 3, 4] ;input_y_label: [[4 3 6 2 5 1]] prediction: [[2 2 5 5 1 1]]
# 117 loss: 11.087072 label_list_original as input x: [4, 6, 2, 3, 5] ;input_y_label: [[5 3 2 6 4 1]] prediction: [[2 2 6 6 1 1]]
# 118 loss: 10.892945 label_list_original as input x: [4, 6, 3, 2, 5] ;input_y_label: [[5 2 3 6 4 1]] prediction: [[2 2 4 6 1 1]]
# 119 loss: 9.986998 label_list_original as input x: [6, 3, 5, 4, 2] ;input_y_label: [[2 4 5 3 6 1]] prediction: [[2 4 5 6 1 1]]
# 120 loss: 10.121225 label_list_original as input x: [3, 4, 6, 5, 2] ;input_y_label: [[2 5 6 4 3 1]] prediction: [[2 4 6 3 1 1]]
# 121 loss: 10.619432 label_list_original as input x: [3, 5, 4, 2, 6] ;input_y_label: [[6 2 4 5 3 1]] prediction: [[2 5 5 5 1 1]]
# 122 loss: 11.363263 label_list_original as input x: [5, 2, 3, 6, 4] ;input_y_label: [[4 6 3 2 5 1]] prediction: [[2 2 5 6 1 1]]
# 123 loss: 11.407374 label_list_original as input x: [2, 5, 3, 4, 6] ;input_y_label: [[6 4 3 5 2 1]] prediction: [[2 5 5 6 1 1]]
# 124 loss: 11.309838 label_list_original as input x: [5, 2, 3, 6, 4] ;input_y_label: [[4 6 3 2 5 1]] prediction: [[2 2 5 5 1 1]]
# 125 loss: 10.946297 label_list_original as input x: [6, 2, 5, 3, 4] ;input_y_label: [[4 3 5 2 6 1]] prediction: [[2 2 5 6 1 1]]
# 126 loss: 10.547846 label_list_original as input x: [6, 5, 4, 2, 3] ;input_y_label: [[3 2 4 5 6 1]] prediction: [[2 2 5 5 1 1]]
# 127 loss: 10.854857 label_list_original as input x: [6, 4, 2, 3, 5] ;input_y_label: [[5 3 2 4 6 1]] prediction: [[2 2 6 6 1 1]]
# 128 loss: 10.87599 label_list_original as input x: [2, 3, 5, 6, 4] ;input_y_label: [[4 6 5 3 2 1]] prediction: [[2 2 5 3 1 1]]
# 129 loss: 10.933453 label_list_original as input x: [6, 2, 4, 3, 5] ;input_y_label: [[5 3 4 2 6 1]] prediction: [[2 2 6 3 1 1]]
# 130 loss: 10.970489 label_list_original as input x: [2, 6, 3, 5, 4] ;input_y_label: [[4 5 3 6 2 1]] prediction: [[2 2 6 6 1 1]]
# 131 loss: 10.462251 label_list_original as input x: [6, 4, 5, 2, 3] ;input_y_label: [[3 2 5 4 6 1]] prediction: [[2 2 5 6 1 1]]
# 132 loss: 10.786625 label_list_original as input x: [5, 3, 4, 2, 6] ;input_y_label: [[6 2 4 3 5 1]] prediction: [[2 4 4 3 1 1]]
# 133 loss: 10.846639 label_list_original as input x: [4, 6, 2, 5, 3] ;input_y_label: [[3 5 2 6 4 1]] prediction: [[2 2 6 6 1 1]]
# 134 loss: 10.719594 label_list_original as input x: [2, 3, 4, 6, 5] ;input_y_label: [[5 6 4 3 2 1]] prediction: [[2 4 4 3 1 1]]
# 135 loss: 10.376724 label_list_original as input x: [6, 2, 3, 4, 5] ;input_y_label: [[5 4 3 2 6 1]] prediction: [[2 2 2 6 1 1]]
# 136 loss: 10.32627 label_list_original as input x: [6, 5, 2, 4, 3] ;input_y_label: [[3 4 2 5 6 1]] prediction: [[2 2 2 6 1 1]]
# 137 loss: 10.690157 label_list_original as input x: [4, 5, 6, 3, 2] ;input_y_label: [[2 3 6 5 4 1]] prediction: [[2 4 5 5 1 1]]
# 138 loss: 10.298378 label_list_original as input x: [3, 5, 4, 6, 2] ;input_y_label: [[2 6 4 5 3 1]] prediction: [[2 4 4 3 1 1]]
# 139 loss: 11.126912 label_list_original as input x: [5, 2, 4, 3, 6] ;input_y_label: [[6 3 4 2 5 1]] prediction: [[2 4 5 2 1 1]]
# 140 loss: 10.649937 label_list_original as input x: [2, 4, 5, 6, 3] ;input_y_label: [[3 6 5 4 2 1]] prediction: [[4 5 5 6 1 1]]
# 141 loss: 9.968323 label_list_original as input x: [3, 6, 5, 2, 4] ;input_y_label: [[4 2 5 6 3 1]] prediction: [[2 2 5 6 1 1]]
# 142 loss: 10.718906 label_list_original as input x: [2, 6, 4, 5, 3] ;input_y_label: [[3 5 4 6 2 1]] prediction: [[4 5 6 2 1 1]]
# 143 loss: 10.9093895 label_list_original as input x: [2, 4, 5, 3, 6] ;input_y_label: [[6 3 5 4 2 1]] prediction: [[4 4 5 6 1 1]]
# 144 loss: 9.964166 label_list_original as input x: [3, 6, 5, 4, 2] ;input_y_label: [[2 4 5 6 3 1]] prediction: [[4 4 5 6 1 1]]
# 145 loss: 10.66872 label_list_original as input x: [5, 2, 6, 4, 3] ;input_y_label: [[3 4 6 2 5 1]] prediction: [[4 4 2 5 1 1]]
# 146 loss: 10.52651 label_list_original as input x: [5, 4, 6, 2, 3] ;input_y_label: [[3 2 6 4 5 1]] prediction: [[4 4 5 5 1 1]]
# 147 loss: 10.339141 label_list_original as input x: [6, 4, 2, 3, 5] ;input_y_label: [[5 3 2 4 6 1]] prediction: [[2 4 2 6 1 1]]
# 148 loss: 10.397446 label_list_original as input x: [3, 6, 4, 2, 5] ;input_y_label: [[5 2 4 6 3 1]] prediction: [[4 4 4 2 1 1]]
# 149 loss: 10.858384 label_list_original as input x: [4, 2, 5, 3, 6] ;input_y_label: [[6 3 5 2 4 1]] prediction: [[3 4 5 6 1 1]]
# 150 loss: 10.370342 label_list_original as input x: [4, 2, 6, 5, 3] ;input_y_label: [[3 5 6 2 4 1]] prediction: [[3 4 6 4 1 1]]
# 151 loss: 10.1230955 label_list_original as input x: [6, 2, 3, 4, 5] ;input_y_label: [[5 4 3 2 6 1]] prediction: [[3 4 2 2 1 1]]
# 152 loss: 10.788785 label_list_original as input x: [4, 2, 3, 5, 6] ;input_y_label: [[6 5 3 2 4 1]] prediction: [[3 4 4 2 1 1]]
# 153 loss: 10.19783 label_list_original as input x: [6, 2, 3, 5, 4] ;input_y_label: [[4 5 3 2 6 1]] prediction: [[3 2 2 2 1 1]]
# 154 loss: 10.384114 label_list_original as input x: [4, 2, 6, 3, 5] ;input_y_label: [[5 3 6 2 4 1]] prediction: [[3 4 2 4 1 1]]
# 155 loss: 10.074719 label_list_original as input x: [2, 5, 4, 6, 3] ;input_y_label: [[3 6 4 5 2 1]] prediction: [[3 5 5 2 1 1]]
# 156 loss: 10.8555155 label_list_original as input x: [5, 3, 6, 2, 4] ;input_y_label: [[4 2 6 3 5 1]] prediction: [[3 5 4 4 1 1]]
# 157 loss: 10.851672 label_list_original as input x: [4, 3, 2, 5, 6] ;input_y_label: [[6 5 2 3 4 1]] prediction: [[3 4 4 4 1 1]]
# 158 loss: 10.512649 label_list_original as input x: [3, 4, 5, 6, 2] ;input_y_label: [[2 6 5 4 3 1]] prediction: [[3 4 4 4 1 1]]
# 159 loss: 9.887824 label_list_original as input x: [6, 4, 5, 2, 3] ;input_y_label: [[3 2 5 4 6 1]] prediction: [[3 5 5 6 1 1]]
# 160 loss: 9.710627 label_list_original as input x: [2, 4, 6, 5, 3] ;input_y_label: [[3 5 6 4 2 1]] prediction: [[3 5 6 2 1 1]]
# 161 loss: 10.091817 label_list_original as input x: [6, 2, 3, 5, 4] ;input_y_label: [[4 5 3 2 6 1]] prediction: [[3 5 2 2 1 1]]
# 162 loss: 10.740275 label_list_original as input x: [4, 3, 6, 2, 5] ;input_y_label: [[5 2 6 3 4 1]] prediction: [[3 3 4 4 1 1]]
# 163 loss: 10.621961 label_list_original as input x: [4, 3, 2, 5, 6] ;input_y_label: [[6 5 2 3 4 1]] prediction: [[3 5 4 4 1 1]]
# 164 loss: 9.919539 label_list_original as input x: [2, 6, 5, 4, 3] ;input_y_label: [[3 4 5 6 2 1]] prediction: [[3 5 2 2 1 1]]
# 165 loss: 10.017492 label_list_original as input x: [2, 3, 4, 5, 6] ;input_y_label: [[6 5 4 3 2 1]] prediction: [[3 5 4 2 1 1]]
# 166 loss: 10.259208 label_list_original as input x: [2, 3, 6, 4, 5] ;input_y_label: [[5 4 6 3 2 1]] prediction: [[3 3 2 2 1 1]]
# 167 loss: 10.912135 label_list_original as input x: [5, 6, 4, 3, 2] ;input_y_label: [[2 3 4 6 5 1]] prediction: [[3 5 5 2 1 1]]
# 168 loss: 10.782614 label_list_original as input x: [4, 3, 5, 6, 2] ;input_y_label: [[2 6 5 3 4 1]] prediction: [[3 5 4 4 1 1]]
# 169 loss: 10.404101 label_list_original as input x: [5, 2, 4, 3, 6] ;input_y_label: [[6 3 4 2 5 1]] prediction: [[3 5 5 2 1 1]]
# 170 loss: 10.379895 label_list_original as input x: [5, 2, 4, 3, 6] ;input_y_label: [[6 3 4 2 5 1]] prediction: [[3 5 5 2 1 1]]
# 171 loss: 10.187249 label_list_original as input x: [2, 5, 4, 3, 6] ;input_y_label: [[6 3 4 5 2 1]] prediction: [[3 5 5 2 2 1]]
# 172 loss: 10.50225 label_list_original as input x: [3, 6, 5, 2, 4] ;input_y_label: [[4 2 5 6 3 1]] prediction: [[3 5 5 2 1 1]]
# 173 loss: 9.985971 label_list_original as input x: [3, 2, 5, 4, 6] ;input_y_label: [[6 4 5 2 3 1]] prediction: [[3 5 5 2 1 1]]
# 174 loss: 10.087082 label_list_original as input x: [2, 6, 3, 4, 5] ;input_y_label: [[5 4 3 6 2 1]] prediction: [[3 3 2 2 1 1]]
# 175 loss: 10.835899 label_list_original as input x: [5, 3, 4, 6, 2] ;input_y_label: [[2 6 4 3 5 1]] prediction: [[3 5 4 2 2 1]]
# 176 loss: 10.967381 label_list_original as input x: [5, 6, 4, 3, 2] ;input_y_label: [[2 3 4 6 5 1]] prediction: [[3 5 5 2 1 1]]
# 177 loss: 9.852859 label_list_original as input x: [4, 5, 2, 6, 3] ;input_y_label: [[3 6 2 5 4 1]] prediction: [[3 5 5 4 4 1]]
# 178 loss: 10.065428 label_list_original as input x: [6, 4, 5, 2, 3] ;input_y_label: [[3 2 5 4 6 1]] prediction: [[3 5 5 4 2 1]]
# 179 loss: 10.981154 label_list_original as input x: [5, 6, 3, 2, 4] ;input_y_label: [[4 2 3 6 5 1]] prediction: [[3 5 5 2 1 1]]
# 180 loss: 10.428081 label_list_original as input x: [4, 3, 5, 2, 6] ;input_y_label: [[6 2 5 3 4 1]] prediction: [[3 5 5 4 1 1]]
# 181 loss: 9.947486 label_list_original as input x: [4, 6, 5, 2, 3] ;input_y_label: [[3 2 5 6 4 1]] prediction: [[3 6 5 4 1 1]]
# 182 loss: 10.397471 label_list_original as input x: [6, 3, 5, 4, 2] ;input_y_label: [[2 4 5 3 6 1]] prediction: [[3 5 5 2 1 1]]
# 183 loss: 9.936961 label_list_original as input x: [3, 5, 2, 4, 6] ;input_y_label: [[6 4 2 5 3 1]] prediction: [[6 5 5 4 1 1]]
# 184 loss: 9.856675 label_list_original as input x: [6, 2, 5, 4, 3] ;input_y_label: [[3 4 5 2 6 1]] prediction: [[3 6 5 2 1 1]]
# 185 loss: 10.241802 label_list_original as input x: [6, 3, 5, 4, 2] ;input_y_label: [[2 4 5 3 6 1]] prediction: [[3 5 5 2 1 1]]
# 186 loss: 9.833647 label_list_original as input x: [4, 5, 6, 2, 3] ;input_y_label: [[3 2 6 5 4 1]] prediction: [[3 6 5 5 4 1]]
# 187 loss: 9.709128 label_list_original as input x: [4, 6, 5, 2, 3] ;input_y_label: [[3 2 5 6 4 1]] prediction: [[3 6 5 4 1 1]]
# 188 loss: 9.868391 label_list_original as input x: [2, 3, 5, 4, 6] ;input_y_label: [[6 4 5 3 2 1]] prediction: [[3 5 5 2 1 1]]
# 189 loss: 9.449116 label_list_original as input x: [4, 2, 5, 6, 3] ;input_y_label: [[3 6 5 2 4 1]] prediction: [[3 6 5 4 1 1]]
# 190 loss: 9.809182 label_list_original as input x: [5, 4, 6, 2, 3] ;input_y_label: [[3 2 6 4 5 1]] prediction: [[3 6 5 5 5 1]]
# 191 loss: 9.915684 label_list_original as input x: [5, 6, 4, 2, 3] ;input_y_label: [[3 2 4 6 5 1]] prediction: [[3 6 5 5 5 1]]
# 192 loss: 10.110463 label_list_original as input x: [4, 5, 3, 6, 2] ;input_y_label: [[2 6 3 5 4 1]] prediction: [[3 5 5 5 4 1]]
# 193 loss: 10.156475 label_list_original as input x: [5, 3, 2, 4, 6] ;input_y_label: [[6 4 2 3 5 1]] prediction: [[3 5 5 5 5 1]]
# 194 loss: 10.030379 label_list_original as input x: [6, 3, 4, 5, 2] ;input_y_label: [[2 5 4 3 6 1]] prediction: [[3 5 4 2 1 1]]
# 195 loss: 9.947904 label_list_original as input x: [3, 6, 5, 4, 2] ;input_y_label: [[2 4 5 6 3 1]] prediction: [[3 5 5 6 1 1]]
# 196 loss: 10.359715 label_list_original as input x: [2, 4, 6, 3, 5] ;input_y_label: [[5 3 6 4 2 1]] prediction: [[3 6 6 5 5 1]]
# 197 loss: 9.940251 label_list_original as input x: [5, 2, 6, 4, 3] ;input_y_label: [[3 4 6 2 5 1]] prediction: [[3 6 5 5 5 1]]
# 198 loss: 10.443427 label_list_original as input x: [6, 2, 3, 5, 4] ;input_y_label: [[4 5 3 2 6 1]] prediction: [[3 2 6 6 6 1]]
# 199 loss: 10.648179 label_list_original as input x: [4, 3, 2, 6, 5] ;input_y_label: [[5 6 2 3 4 1]] prediction: [[3 6 4 4 5 1]]
# 200 loss: 9.254931 label_list_original as input x: [6, 5, 4, 2, 3] ;input_y_label: [[3 2 4 5 6 1]] prediction: [[3 2 5 5 6 1]]
# 201 loss: 10.742313 label_list_original as input x: [3, 2, 6, 5, 4] ;input_y_label: [[4 5 6 2 3 1]] prediction: [[3 2 6 4 1 1]]
# 202 loss: 9.64493 label_list_original as input x: [3, 4, 5, 6, 2] ;input_y_label: [[2 6 5 4 3 1]] prediction: [[3 4 5 4 1 1]]
# 203 loss: 9.620945 label_list_original as input x: [3, 4, 5, 6, 2] ;input_y_label: [[2 6 5 4 3 1]] prediction: [[3 4 5 4 1 1]]
# 204 loss: 10.3951 label_list_original as input x: [6, 2, 3, 4, 5] ;input_y_label: [[5 4 3 2 6 1]] prediction: [[3 2 2 6 6 1]]
# 205 loss: 10.1506195 label_list_original as input x: [2, 3, 5, 4, 6] ;input_y_label: [[6 4 5 3 2 1]] prediction: [[3 4 5 6 6 1]]
# 206 loss: 10.100275 label_list_original as input x: [5, 4, 3, 2, 6] ;input_y_label: [[6 2 3 4 5 1]] prediction: [[3 2 5 5 5 1]]
# 207 loss: 9.965739 label_list_original as input x: [4, 3, 6, 5, 2] ;input_y_label: [[2 5 6 3 4 1]] prediction: [[3 4 4 4 1 1]]
# 208 loss: 9.83842 label_list_original as input x: [2, 4, 6, 5, 3] ;input_y_label: [[3 5 6 4 2 1]] prediction: [[3 6 6 4 1 1]]
# 209 loss: 10.042435 label_list_original as input x: [4, 6, 2, 3, 5] ;input_y_label: [[5 3 2 6 4 1]] prediction: [[3 2 2 5 4 1]]
# 210 loss: 10.515951 label_list_original as input x: [2, 5, 3, 6, 4] ;input_y_label: [[4 6 3 5 2 1]] prediction: [[3 2 5 5 4 1]]
# 211 loss: 10.166211 label_list_original as input x: [2, 6, 4, 5, 3] ;input_y_label: [[3 5 4 6 2 1]] prediction: [[3 2 6 2 1 1]]
# 212 loss: 10.362051 label_list_original as input x: [2, 6, 5, 3, 4] ;input_y_label: [[4 3 5 6 2 1]] prediction: [[3 2 2 6 4 1]]
# 213 loss: 9.8086605 label_list_original as input x: [5, 6, 4, 3, 2] ;input_y_label: [[2 3 4 6 5 1]] prediction: [[3 4 5 5 4 1]]
# 214 loss: 10.289847 label_list_original as input x: [5, 2, 3, 6, 4] ;input_y_label: [[4 6 3 2 5 1]] prediction: [[3 2 5 5 4 1]]
# 215 loss: 9.878252 label_list_original as input x: [2, 3, 4, 5, 6] ;input_y_label: [[6 5 4 3 2 1]] prediction: [[3 4 4 3 1 1]]
# 216 loss: 10.081636 label_list_original as input x: [4, 2, 3, 6, 5] ;input_y_label: [[5 6 3 2 4 1]] prediction: [[3 3 4 2 4 1]]
# 217 loss: 9.560616 label_list_original as input x: [4, 6, 5, 3, 2] ;input_y_label: [[2 3 5 6 4 1]] prediction: [[3 3 5 6 4 1]]
# 218 loss: 9.880203 label_list_original as input x: [4, 5, 3, 6, 2] ;input_y_label: [[2 6 3 5 4 1]] prediction: [[3 6 4 4 4 1]]
# 219 loss: 9.946537 label_list_original as input x: [3, 2, 4, 6, 5] ;input_y_label: [[5 6 4 2 3 1]] prediction: [[3 6 4 2 4 1]]
# 220 loss: 10.231217 label_list_original as input x: [3, 6, 2, 4, 5] ;input_y_label: [[5 4 2 6 3 1]] prediction: [[3 6 2 6 4 1]]
# 221 loss: 9.89035 label_list_original as input x: [2, 4, 3, 6, 5] ;input_y_label: [[5 6 3 4 2 1]] prediction: [[3 6 4 2 2 1]]
# 222 loss: 9.65669 label_list_original as input x: [4, 3, 5, 6, 2] ;input_y_label: [[2 6 5 3 4 1]] prediction: [[3 6 4 4 4 1]]
# 223 loss: 9.513449 label_list_original as input x: [6, 4, 5, 2, 3] ;input_y_label: [[3 2 5 4 6 1]] prediction: [[3 6 5 4 3 1]]
# 224 loss: 9.706395 label_list_original as input x: [5, 4, 6, 2, 3] ;input_y_label: [[3 2 6 4 5 1]] prediction: [[3 6 5 4 3 1]]
# 225 loss: 9.414987 label_list_original as input x: [3, 4, 6, 5, 2] ;input_y_label: [[2 5 6 4 3 1]] prediction: [[2 6 6 4 3 1]]
# 226 loss: 9.780577 label_list_original as input x: [2, 6, 5, 4, 3] ;input_y_label: [[3 4 5 6 2 1]] prediction: [[3 6 5 6 4 1]]
# 227 loss: 9.464376 label_list_original as input x: [4, 6, 5, 3, 2] ;input_y_label: [[2 3 5 6 4 1]] prediction: [[3 6 5 6 4 1]]
# 228 loss: 10.062917 label_list_original as input x: [2, 6, 4, 3, 5] ;input_y_label: [[5 3 4 6 2 1]] prediction: [[3 6 6 2 4 1]]
# 229 loss: 10.269801 label_list_original as input x: [6, 3, 2, 5, 4] ;input_y_label: [[4 5 2 3 6 1]] prediction: [[2 6 6 6 4 1]]
# 230 loss: 9.658618 label_list_original as input x: [6, 5, 4, 3, 2] ;input_y_label: [[2 3 4 5 6 1]] prediction: [[2 5 5 6 6 1]]
# 231 loss: 9.883448 label_list_original as input x: [5, 6, 4, 3, 2] ;input_y_label: [[2 3 4 6 5 1]] prediction: [[2 6 6 6 4 1]]
# 232 loss: 9.69845 label_list_original as input x: [4, 5, 3, 6, 2] ;input_y_label: [[2 6 3 5 4 1]] prediction: [[2 5 5 4 4 1]]
# 233 loss: 9.967702 label_list_original as input x: [6, 3, 5, 2, 4] ;input_y_label: [[4 2 5 3 6 1]] prediction: [[2 5 5 6 6 1]]
# 234 loss: 9.597348 label_list_original as input x: [5, 4, 6, 2, 3] ;input_y_label: [[3 2 6 4 5 1]] prediction: [[2 6 5 4 4 1]]
# 235 loss: 9.78747 label_list_original as input x: [2, 4, 5, 3, 6] ;input_y_label: [[6 3 5 4 2 1]] prediction: [[3 5 5 6 6 1]]
# 236 loss: 9.968261 label_list_original as input x: [4, 2, 5, 3, 6] ;input_y_label: [[6 3 5 2 4 1]] prediction: [[3 5 5 6 4 1]]
# 237 loss: 9.660007 label_list_original as input x: [5, 4, 3, 6, 2] ;input_y_label: [[2 6 3 4 5 1]] prediction: [[2 5 5 4 6 1]]
# 238 loss: 10.132086 label_list_original as input x: [2, 6, 3, 4, 5] ;input_y_label: [[5 4 3 6 2 1]] prediction: [[3 6 6 6 4 1]]
# 239 loss: 9.622235 label_list_original as input x: [2, 4, 6, 3, 5] ;input_y_label: [[5 3 6 4 2 1]] prediction: [[3 6 6 4 4 1]]
# 240 loss: 10.108355 label_list_original as input x: [6, 2, 5, 3, 4] ;input_y_label: [[4 3 5 2 6 1]] prediction: [[2 5 5 6 6 1]]
# 241 loss: 9.667493 label_list_original as input x: [2, 4, 3, 6, 5] ;input_y_label: [[5 6 3 4 2 1]] prediction: [[3 6 4 4 2 1]]
# 242 loss: 9.708409 label_list_original as input x: [2, 3, 4, 6, 5] ;input_y_label: [[5 6 4 3 2 1]] prediction: [[3 6 4 3 4 1]]
# 243 loss: 10.155524 label_list_original as input x: [3, 2, 5, 4, 6] ;input_y_label: [[6 4 5 2 3 1]] prediction: [[2 5 5 6 4 1]]
# 244 loss: 9.382513 label_list_original as input x: [3, 6, 5, 4, 2] ;input_y_label: [[2 4 5 6 3 1]] prediction: [[2 5 5 6 4 1]]
# 245 loss: 10.017342 label_list_original as input x: [5, 4, 2, 3, 6] ;input_y_label: [[6 3 2 4 5 1]] prediction: [[2 5 5 4 4 1]]
# 246 loss: 9.552659 label_list_original as input x: [2, 6, 5, 4, 3] ;input_y_label: [[3 4 5 6 2 1]] prediction: [[3 5 5 6 4 1]]
# 247 loss: 10.091648 label_list_original as input x: [3, 5, 4, 2, 6] ;input_y_label: [[6 2 4 5 3 1]] prediction: [[2 5 4 5 4 1]]
# 248 loss: 9.015937 label_list_original as input x: [4, 6, 5, 3, 2] ;input_y_label: [[2 3 5 6 4 1]] prediction: [[2 5 5 6 4 1]]
# 249 loss: 9.472565 label_list_original as input x: [3, 6, 4, 5, 2] ;input_y_label: [[2 5 4 6 3 1]] prediction: [[2 5 4 3 1 1]]
# 250 loss: 9.597166 label_list_original as input x: [5, 4, 3, 6, 2] ;input_y_label: [[2 6 3 4 5 1]] prediction: [[2 3 4 4 2 1]]
# 251 loss: 9.859476 label_list_original as input x: [3, 2, 5, 4, 6] ;input_y_label: [[6 4 5 2 3 1]] prediction: [[2 5 5 4 4 1]]
# 252 loss: 10.363904 label_list_original as input x: [5, 2, 6, 3, 4] ;input_y_label: [[4 3 6 2 5 1]] prediction: [[2 5 5 4 4 1]]
# 253 loss: 10.120635 label_list_original as input x: [3, 5, 6, 2, 4] ;input_y_label: [[4 2 6 5 3 1]] prediction: [[2 5 5 4 4 1]]
# 254 loss: 9.186135 label_list_original as input x: [4, 6, 5, 2, 3] ;input_y_label: [[3 2 5 6 4 1]] prediction: [[2 5 5 4 4 1]]
# 255 loss: 9.278809 label_list_original as input x: [6, 5, 4, 3, 2] ;input_y_label: [[2 3 4 5 6 1]] prediction: [[2 5 5 5 6 1]]
# 256 loss: 9.940753 label_list_original as input x: [4, 3, 6, 2, 5] ;input_y_label: [[5 2 6 3 4 1]] prediction: [[2 3 4 4 4 1]]
# 257 loss: 9.415243 label_list_original as input x: [2, 4, 6, 3, 5] ;input_y_label: [[5 3 6 4 2 1]] prediction: [[2 6 6 4 2 1]]
# 258 loss: 9.966959 label_list_original as input x: [5, 2, 3, 4, 6] ;input_y_label: [[6 4 3 2 5 1]] prediction: [[2 5 5 5 4 1]]
# 259 loss: 10.121355 label_list_original as input x: [3, 6, 2, 5, 4] ;input_y_label: [[4 5 2 6 3 1]] prediction: [[2 5 6 6 4 1]]
# 260 loss: 9.992754 label_list_original as input x: [6, 5, 3, 2, 4] ;input_y_label: [[4 2 3 5 6 1]] prediction: [[2 2 5 5 6 1]]
# 261 loss: 9.999751 label_list_original as input x: [5, 2, 6, 4, 3] ;input_y_label: [[3 4 6 2 5 1]] prediction: [[2 6 5 5 4 1]]
# 262 loss: 9.674732 label_list_original as input x: [6, 2, 5, 4, 3] ;input_y_label: [[3 4 5 2 6 1]] prediction: [[2 5 5 6 6 1]]
# 263 loss: 9.946583 label_list_original as input x: [3, 2, 6, 5, 4] ;input_y_label: [[4 5 6 2 3 1]] prediction: [[2 6 6 3 4 1]]
# 264 loss: 9.806815 label_list_original as input x: [4, 6, 3, 2, 5] ;input_y_label: [[5 2 3 6 4 1]] prediction: [[2 6 6 6 4 1]]
# 265 loss: 9.9060135 label_list_original as input x: [3, 5, 2, 6, 4] ;input_y_label: [[4 6 2 5 3 1]] prediction: [[2 6 5 5 3 1]]
# 266 loss: 9.413832 label_list_original as input x: [4, 5, 3, 6, 2] ;input_y_label: [[2 6 3 5 4 1]] prediction: [[2 6 5 5 6 1]]
# 267 loss: 10.187192 label_list_original as input x: [5, 3, 2, 6, 4] ;input_y_label: [[4 6 2 3 5 1]] prediction: [[2 6 5 5 5 1]]
# 268 loss: 9.685944 label_list_original as input x: [2, 6, 3, 5, 4] ;input_y_label: [[4 5 3 6 2 1]] prediction: [[2 6 6 6 2 1]]
# 269 loss: 9.264459 label_list_original as input x: [5, 4, 6, 3, 2] ;input_y_label: [[2 3 6 4 5 1]] prediction: [[2 6 6 5 2 1]]
# 270 loss: 10.026593 label_list_original as input x: [5, 3, 2, 6, 4] ;input_y_label: [[4 6 2 3 5 1]] prediction: [[2 6 5 5 5 1]]
# 271 loss: 9.576887 label_list_original as input x: [4, 2, 6, 5, 3] ;input_y_label: [[3 5 6 2 4 1]] prediction: [[2 6 6 2 4 1]]
# 272 loss: 9.303953 label_list_original as input x: [4, 6, 3, 5, 2] ;input_y_label: [[2 5 3 6 4 1]] prediction: [[2 6 6 6 2 1]]
# 273 loss: 10.011467 label_list_original as input x: [5, 3, 4, 2, 6] ;input_y_label: [[6 2 4 3 5 1]] prediction: [[2 4 5 5 2 1]]
# 274 loss: 9.364386 label_list_original as input x: [4, 5, 3, 6, 2] ;input_y_label: [[2 6 3 5 4 1]] prediction: [[2 6 5 5 6 1]]
# 275 loss: 9.654016 label_list_original as input x: [5, 6, 4, 2, 3] ;input_y_label: [[3 2 4 6 5 1]] prediction: [[2 6 6 6 5 1]]
# 276 loss: 9.631201 label_list_original as input x: [2, 6, 3, 5, 4] ;input_y_label: [[4 5 3 6 2 1]] prediction: [[2 6 6 6 2 1]]
# 277 loss: 9.603903 label_list_original as input x: [5, 2, 6, 3, 4] ;input_y_label: [[4 3 6 2 5 1]] prediction: [[2 6 6 5 5 1]]
# 278 loss: 9.870272 label_list_original as input x: [6, 2, 4, 5, 3] ;input_y_label: [[3 5 4 2 6 1]] prediction: [[2 6 6 6 6 1]]
# 279 loss: 8.999367 label_list_original as input x: [4, 5, 6, 3, 2] ;input_y_label: [[2 3 6 5 4 1]] prediction: [[2 6 6 5 4 1]]
# 280 loss: 9.866528 label_list_original as input x: [4, 6, 3, 2, 5] ;input_y_label: [[5 2 3 6 4 1]] prediction: [[2 6 6 6 5 1]]
# 281 loss: 9.777353 label_list_original as input x: [4, 2, 3, 6, 5] ;input_y_label: [[5 6 3 2 4 1]] prediction: [[2 6 3 2 5 1]]
# 282 loss: 9.196379 label_list_original as input x: [4, 6, 3, 5, 2] ;input_y_label: [[2 5 3 6 4 1]] prediction: [[2 6 6 6 5 1]]
# 283 loss: 9.730231 label_list_original as input x: [4, 2, 3, 6, 5] ;input_y_label: [[5 6 3 2 4 1]] prediction: [[2 6 3 2 5 1]]
# 284 loss: 9.91829 label_list_original as input x: [4, 2, 5, 3, 6] ;input_y_label: [[6 3 5 2 4 1]] prediction: [[2 3 5 6 6 1]]
# 285 loss: 9.846218 label_list_original as input x: [2, 6, 3, 4, 5] ;input_y_label: [[5 4 3 6 2 1]] prediction: [[2 6 6 6 5 1]]
# 286 loss: 9.682384 label_list_original as input x: [2, 4, 5, 3, 6] ;input_y_label: [[6 3 5 4 2 1]] prediction: [[3 3 5 6 2 1]]
# 287 loss: 10.01846 label_list_original as input x: [3, 2, 4, 5, 6] ;input_y_label: [[6 5 4 2 3 1]] prediction: [[2 4 3 3 6 1]]
# 288 loss: 9.805281 label_list_original as input x: [3, 6, 2, 5, 4] ;input_y_label: [[4 5 2 6 3 1]] prediction: [[2 6 6 6 4 1]]
# 289 loss: 9.315939 label_list_original as input x: [5, 3, 6, 4, 2] ;input_y_label: [[2 4 6 3 5 1]] prediction: [[2 3 6 5 5 1]]
# 290 loss: 9.998627 label_list_original as input x: [6, 3, 4, 2, 5] ;input_y_label: [[5 2 4 3 6 1]] prediction: [[2 3 3 3 2 1]]
# 291 loss: 9.724184 label_list_original as input x: [6, 2, 4, 5, 3] ;input_y_label: [[3 5 4 2 6 1]] prediction: [[2 6 6 6 6 1]]
# 292 loss: 9.711137 label_list_original as input x: [3, 6, 2, 5, 4] ;input_y_label: [[4 5 2 6 3 1]] prediction: [[2 6 6 6 4 1]]
# 293 loss: 9.497363 label_list_original as input x: [3, 2, 4, 6, 5] ;input_y_label: [[5 6 4 2 3 1]] prediction: [[2 6 3 2 4 1]]
# 294 loss: 9.5332 label_list_original as input x: [6, 4, 5, 2, 3] ;input_y_label: [[3 2 5 4 6 1]] prediction: [[2 2 5 6 2 1]]
# 295 loss: 9.388008 label_list_original as input x: [4, 5, 2, 6, 3] ;input_y_label: [[3 6 2 5 4 1]] prediction: [[2 6 5 4 4 1]]
# 296 loss: 9.6910305 label_list_original as input x: [5, 2, 3, 4, 6] ;input_y_label: [[6 4 3 2 5 1]] prediction: [[2 4 5 2 4 1]]
# 297 loss: 9.368444 label_list_original as input x: [5, 4, 3, 6, 2] ;input_y_label: [[2 6 3 4 5 1]] prediction: [[2 3 4 4 2 1]]
# 298 loss: 9.514844 label_list_original as input x: [3, 6, 2, 5, 4] ;input_y_label: [[4 5 2 6 3 1]] prediction: [[2 5 6 6 4 1]]
# 299 loss: 9.36402 label_list_original as input x: [2, 6, 5, 4, 3] ;input_y_label: [[3 4 5 6 2 1]] prediction: [[3 5 5 6 2 1]]
# 300 loss: 9.587482 label_list_original as input x: [6, 4, 2, 3, 5] ;input_y_label: [[5 3 2 4 6 1]] prediction: [[2 3 6 6 2 1]]
# 301 loss: 9.426686 label_list_original as input x: [6, 2, 4, 3, 5] ;input_y_label: [[5 3 4 2 6 1]] prediction: [[2 3 6 2 6 1]]
# 302 loss: 9.66276 label_list_original as input x: [3, 6, 4, 2, 5] ;input_y_label: [[5 2 4 6 3 1]] prediction: [[2 6 4 3 4 1]]
# 303 loss: 9.094069 label_list_original as input x: [4, 2, 6, 5, 3] ;input_y_label: [[3 5 6 2 4 1]] prediction: [[5 5 6 4 4 1]]
# 304 loss: 9.046829 label_list_original as input x: [2, 3, 4, 6, 5] ;input_y_label: [[5 6 4 3 2 1]] prediction: [[5 6 4 2 2 1]]
# 305 loss: 9.955763 label_list_original as input x: [5, 3, 2, 4, 6] ;input_y_label: [[6 4 2 3 5 1]] prediction: [[5 4 2 4 4 1]]
# 306 loss: 9.740408 label_list_original as input x: [5, 2, 3, 4, 6] ;input_y_label: [[6 4 3 2 5 1]] prediction: [[5 4 2 2 4 1]]
# 307 loss: 9.348182 label_list_original as input x: [2, 5, 4, 6, 3] ;input_y_label: [[3 6 4 5 2 1]] prediction: [[5 5 5 2 2 1]]
# 308 loss: 9.518299 label_list_original as input x: [6, 5, 2, 3, 4] ;input_y_label: [[4 3 2 5 6 1]] prediction: [[5 5 2 6 6 1]]
# 309 loss: 9.159875 label_list_original as input x: [2, 6, 4, 3, 5] ;input_y_label: [[5 3 4 6 2 1]] prediction: [[5 6 6 2 2 1]]
# 310 loss: 9.092233 label_list_original as input x: [4, 6, 2, 5, 3] ;input_y_label: [[3 5 2 6 4 1]] prediction: [[5 5 6 6 4 1]]
# 311 loss: 9.63146 label_list_original as input x: [2, 5, 3, 4, 6] ;input_y_label: [[6 4 3 5 2 1]] prediction: [[5 4 5 2 2 1]]
# 312 loss: 9.704812 label_list_original as input x: [4, 3, 2, 5, 6] ;input_y_label: [[6 5 2 3 4 1]] prediction: [[5 5 4 4 2 1]]
# 313 loss: 9.564499 label_list_original as input x: [6, 5, 4, 2, 3] ;input_y_label: [[3 2 4 5 6 1]] prediction: [[5 5 5 2 6 1]]
# 314 loss: 9.647152 label_list_original as input x: [6, 5, 3, 4, 2] ;input_y_label: [[2 4 3 5 6 1]] prediction: [[5 4 3 2 6 1]]
# 315 loss: 9.578289 label_list_original as input x: [6, 3, 5, 4, 2] ;input_y_label: [[2 4 5 3 6 1]] prediction: [[5 4 5 6 2 1]]
# 316 loss: 10.131301 label_list_original as input x: [4, 5, 3, 2, 6] ;input_y_label: [[6 2 3 5 4 1]] prediction: [[5 5 4 4 4 1]]
# 317 loss: 9.060711 label_list_original as input x: [2, 6, 3, 5, 4] ;input_y_label: [[4 5 3 6 2 1]] prediction: [[5 5 6 2 2 1]]
# 318 loss: 8.965499 label_list_original as input x: [2, 6, 5, 4, 3] ;input_y_label: [[3 4 5 6 2 1]] prediction: [[5 5 5 6 2 1]]
# 319 loss: 9.44627 label_list_original as input x: [4, 3, 2, 6, 5] ;input_y_label: [[5 6 2 3 4 1]] prediction: [[5 3 4 4 4 1]]
# 320 loss: 10.018235 label_list_original as input x: [4, 3, 5, 2, 6] ;input_y_label: [[6 2 5 3 4 1]] prediction: [[5 5 4 4 2 1]]
# 321 loss: 9.667129 label_list_original as input x: [4, 3, 2, 5, 6] ;input_y_label: [[6 5 2 3 4 1]] prediction: [[5 5 3 4 4 1]]
# 322 loss: 9.334259 label_list_original as input x: [6, 3, 2, 5, 4] ;input_y_label: [[4 5 2 3 6 1]] prediction: [[5 5 3 6 6 1]]
# 323 loss: 8.997744 label_list_original as input x: [2, 3, 6, 5, 4] ;input_y_label: [[4 5 6 3 2 1]] prediction: [[5 5 6 2 2 1]]
# 324 loss: 8.832631 label_list_original as input x: [2, 3, 4, 6, 5] ;input_y_label: [[5 6 4 3 2 1]] prediction: [[5 6 3 2 2 1]]
# 325 loss: 8.835581 label_list_original as input x: [4, 2, 3, 6, 5] ;input_y_label: [[5 6 3 2 4 1]] prediction: [[5 3 3 2 4 1]]
# 326 loss: 8.746109 label_list_original as input x: [2, 3, 4, 6, 5] ;input_y_label: [[5 6 4 3 2 1]] prediction: [[5 6 3 2 2 1]]
# 327 loss: 8.670944 label_list_original as input x: [2, 4, 3, 6, 5] ;input_y_label: [[5 6 3 4 2 1]] prediction: [[5 3 3 2 2 1]]
# 328 loss: 9.410898 label_list_original as input x: [6, 4, 3, 2, 5] ;input_y_label: [[5 2 3 4 6 1]] prediction: [[5 3 3 6 2 1]]
# 329 loss: 9.174044 label_list_original as input x: [6, 3, 2, 5, 4] ;input_y_label: [[4 5 2 3 6 1]] prediction: [[5 5 3 3 6 1]]
# 330 loss: 9.612993 label_list_original as input x: [3, 4, 5, 2, 6] ;input_y_label: [[6 2 5 4 3 1]] prediction: [[5 5 5 3 2 1]]
# 331 loss: 9.325703 label_list_original as input x: [4, 3, 6, 2, 5] ;input_y_label: [[5 2 6 3 4 1]] prediction: [[5 3 3 3 2 1]]
# 332 loss: 10.07487 label_list_original as input x: [5, 4, 3, 2, 6] ;input_y_label: [[6 2 3 4 5 1]] prediction: [[5 5 3 4 2 1]]
# 333 loss: 9.6298895 label_list_original as input x: [4, 3, 5, 6, 2] ;input_y_label: [[2 6 5 3 4 1]] prediction: [[5 5 3 3 2 1]]
# 334 loss: 8.696569 label_list_original as input x: [2, 3, 6, 5, 4] ;input_y_label: [[4 5 6 3 2 1]] prediction: [[5 5 3 3 2 1]]
# 335 loss: 9.429766 label_list_original as input x: [6, 3, 5, 4, 2] ;input_y_label: [[2 4 5 3 6 1]] prediction: [[5 5 3 3 2 1]]
# 336 loss: 9.476435 label_list_original as input x: [4, 3, 5, 6, 2] ;input_y_label: [[2 6 5 3 4 1]] prediction: [[5 5 3 3 2 1]]
# 337 loss: 8.667196 label_list_original as input x: [2, 3, 6, 5, 4] ;input_y_label: [[4 5 6 3 2 1]] prediction: [[5 5 3 3 2 1]]
# 338 loss: 9.388281 label_list_original as input x: [2, 6, 5, 3, 4] ;input_y_label: [[4 3 5 6 2 1]] prediction: [[5 5 5 6 3 1]]
# 339 loss: 9.267104 label_list_original as input x: [3, 6, 5, 4, 2] ;input_y_label: [[2 4 5 6 3 1]] prediction: [[5 5 3 3 3 1]]
# 340 loss: 10.051997 label_list_original as input x: [6, 5, 4, 2, 3] ;input_y_label: [[3 2 4 5 6 1]] prediction: [[5 5 5 3 3 1]]
# 341 loss: 8.6714 label_list_original as input x: [2, 4, 3, 5, 6] ;input_y_label: [[6 5 3 4 2 1]] prediction: [[5 5 3 2 2 1]]
# 342 loss: 10.136694 label_list_original as input x: [5, 4, 2, 6, 3] ;input_y_label: [[3 6 2 4 5 1]] prediction: [[5 5 5 4 3 1]]
# 343 loss: 8.391418 label_list_original as input x: [4, 2, 3, 6, 5] ;input_y_label: [[5 6 3 2 4 1]] prediction: [[5 6 3 2 4 1]]
# 344 loss: 8.763038 label_list_original as input x: [4, 2, 3, 5, 6] ;input_y_label: [[6 5 3 2 4 1]] prediction: [[5 5 3 2 4 1]]
# 345 loss: 9.710833 label_list_original as input x: [5, 2, 3, 6, 4] ;input_y_label: [[4 6 3 2 5 1]] prediction: [[5 5 3 2 4 1]]
# 346 loss: 9.182865 label_list_original as input x: [3, 6, 4, 2, 5] ;input_y_label: [[5 2 4 6 3 1]] prediction: [[5 6 3 3 3 1]]
# 347 loss: 9.148224 label_list_original as input x: [4, 2, 6, 5, 3] ;input_y_label: [[3 5 6 2 4 1]] prediction: [[5 5 6 3 4 1]]
# 348 loss: 9.147254 label_list_original as input x: [2, 6, 4, 3, 5] ;input_y_label: [[5 3 4 6 2 1]] prediction: [[5 6 6 2 2 1]]
# 349 loss: 9.212549 label_list_original as input x: [2, 4, 5, 6, 3] ;input_y_label: [[3 6 5 4 2 1]] prediction: [[5 5 5 3 2 1]]
# 350 loss: 9.813077 label_list_original as input x: [5, 3, 4, 2, 6] ;input_y_label: [[6 2 4 3 5 1]] prediction: [[5 5 5 3 2 1]]
# 351 loss: 9.258156 label_list_original as input x: [3, 6, 4, 5, 2] ;input_y_label: [[2 5 4 6 3 1]] prediction: [[5 5 6 3 3 1]]
# 352 loss: 8.822146 label_list_original as input x: [3, 2, 5, 4, 6] ;input_y_label: [[6 4 5 2 3 1]] prediction: [[5 5 5 3 3 1]]
# 353 loss: 9.722502 label_list_original as input x: [6, 4, 5, 2, 3] ;input_y_label: [[3 2 5 4 6 1]] prediction: [[5 5 5 6 3 1]]
# 354 loss: 9.242643 label_list_original as input x: [3, 6, 4, 2, 5] ;input_y_label: [[5 2 4 6 3 1]] prediction: [[5 6 3 3 3 1]]
# 355 loss: 9.310799 label_list_original as input x: [2, 5, 3, 4, 6] ;input_y_label: [[6 4 3 5 2 1]] prediction: [[5 5 5 2 2 1]]
# 356 loss: 9.357075 label_list_original as input x: [4, 6, 5, 2, 3] ;input_y_label: [[3 2 5 6 4 1]] prediction: [[5 5 5 6 4 1]]
# 357 loss: 9.429515 label_list_original as input x: [5, 2, 3, 4, 6] ;input_y_label: [[6 4 3 2 5 1]] prediction: [[5 5 5 2 4 1]]
# 358 loss: 9.458929 label_list_original as input x: [3, 5, 2, 6, 4] ;input_y_label: [[4 6 2 5 3 1]] prediction: [[5 5 5 4 4 1]]
# 359 loss: 8.882074 label_list_original as input x: [3, 4, 6, 5, 2] ;input_y_label: [[2 5 6 4 3 1]] prediction: [[5 5 6 4 2 1]]
# 360 loss: 9.990316 label_list_original as input x: [5, 6, 3, 4, 2] ;input_y_label: [[2 4 3 6 5 1]] prediction: [[5 5 5 2 4 1]]
# 361 loss: 9.602114 label_list_original as input x: [3, 5, 6, 4, 2] ;input_y_label: [[2 4 6 5 3 1]] prediction: [[5 5 5 4 3 1]]
# 362 loss: 8.329508 label_list_original as input x: [4, 2, 3, 6, 5] ;input_y_label: [[5 6 3 2 4 1]] prediction: [[5 6 3 2 4 1]]
# 363 loss: 9.5837555 label_list_original as input x: [3, 5, 6, 2, 4] ;input_y_label: [[4 2 6 5 3 1]] prediction: [[5 5 5 4 4 1]]
# 364 loss: 8.570253 label_list_original as input x: [2, 4, 3, 5, 6] ;input_y_label: [[6 5 3 4 2 1]] prediction: [[6 5 3 2 2 1]]
# 365 loss: 8.88983 label_list_original as input x: [3, 2, 6, 5, 4] ;input_y_label: [[4 5 6 2 3 1]] prediction: [[5 5 6 3 3 1]]
# 366 loss: 9.527921 label_list_original as input x: [5, 3, 2, 6, 4] ;input_y_label: [[4 6 2 3 5 1]] prediction: [[6 6 5 4 4 1]]
# 367 loss: 9.822989 label_list_original as input x: [5, 4, 6, 2, 3] ;input_y_label: [[3 2 6 4 5 1]] prediction: [[6 6 5 4 2 1]]
# 368 loss: 9.855748 label_list_original as input x: [2, 5, 6, 4, 3] ;input_y_label: [[3 4 6 5 2 1]] prediction: [[6 6 5 2 3 1]]
# 369 loss: 8.539165 label_list_original as input x: [3, 2, 4, 6, 5] ;input_y_label: [[5 6 4 2 3 1]] prediction: [[6 6 4 2 3 1]]
# 370 loss: 9.383193 label_list_original as input x: [4, 6, 2, 5, 3] ;input_y_label: [[3 5 2 6 4 1]] prediction: [[5 6 6 6 4 1]]
# 371 loss: 8.881383 label_list_original as input x: [3, 5, 4, 6, 2] ;input_y_label: [[2 6 4 5 3 1]] prediction: [[6 6 4 3 3 1]]
# 372 loss: 8.900275 label_list_original as input x: [3, 5, 2, 6, 4] ;input_y_label: [[4 6 2 5 3 1]] prediction: [[6 6 5 3 3 1]]
# 373 loss: 9.390507 label_list_original as input x: [4, 6, 2, 5, 3] ;input_y_label: [[3 5 2 6 4 1]] prediction: [[6 6 6 6 4 1]]
# 374 loss: 8.685276 label_list_original as input x: [3, 4, 6, 5, 2] ;input_y_label: [[2 5 6 4 3 1]] prediction: [[6 6 6 3 3 1]]
# 375 loss: 9.04646 label_list_original as input x: [2, 4, 5, 6, 3] ;input_y_label: [[3 6 5 4 2 1]] prediction: [[6 6 5 2 2 1]]
# ...
# 1376 loss: 2.8770266 label_list_original as input x: [3, 5, 2, 4, 6] ;input_y_label: [[6 4 2 5 3 1]] prediction: [[6 4 2 5 3 1]]
# 1377 loss: 3.0284085 label_list_original as input x: [3, 6, 4, 5, 2] ;input_y_label: [[2 5 4 6 3 1]] prediction: [[2 5 4 6 3 1]]
# 1378 loss: 2.9411778 label_list_original as input x: [4, 5, 3, 6, 2] ;input_y_label: [[2 6 3 5 4 1]] prediction: [[2 6 3 5 4 1]]
# 1379 loss: 3.1568165 label_list_original as input x: [3, 5, 2, 6, 4] ;input_y_label: [[4 6 2 5 3 1]] prediction: [[6 6 2 5 3 1]]
# 1380 loss: 3.2353227 label_list_original as input x: [6, 3, 4, 5, 2] ;input_y_label: [[2 5 4 3 6 1]] prediction: [[2 5 4 3 6 1]]
# 1381 loss: 3.3609657 label_list_original as input x: [2, 3, 6, 4, 5] ;input_y_label: [[5 4 6 3 2 1]] prediction: [[5 4 6 3 2 1]]
# 1382 loss: 3.3097382 label_list_original as input x: [4, 2, 3, 6, 5] ;input_y_label: [[5 6 3 2 4 1]] prediction: [[5 6 3 2 4 1]]
# 1383 loss: 3.5720606 label_list_original as input x: [6, 4, 5, 2, 3] ;input_y_label: [[3 2 5 4 6 1]] prediction: [[3 2 5 4 6 1]]
# 1384 loss: 3.2575178 label_list_original as input x: [3, 5, 4, 2, 6] ;input_y_label: [[6 2 4 5 3 1]] prediction: [[6 2 4 5 3 1]]
# 1385 loss: 3.175229 label_list_original as input x: [4, 5, 6, 2, 3] ;input_y_label: [[3 2 6 5 4 1]] prediction: [[3 2 6 5 4 1]]
# 1386 loss: 2.9010012 label_list_original as input x: [3, 6, 2, 5, 4] ;input_y_label: [[4 5 2 6 3 1]] prediction: [[4 5 2 6 3 1]]
# 1387 loss: 2.9267285 label_list_original as input x: [3, 2, 6, 5, 4] ;input_y_label: [[4 5 6 2 3 1]] prediction: [[4 5 6 2 3 1]]
# 1388 loss: 2.8840566 label_list_original as input x: [3, 6, 4, 5, 2] ;input_y_label: [[2 5 4 6 3 1]] prediction: [[2 5 4 6 3 1]]
# 1389 loss: 3.4809694 label_list_original as input x: [2, 4, 3, 5, 6] ;input_y_label: [[6 5 3 4 2 1]] prediction: [[6 5 3 4 2 1]]
# 1390 loss: 3.0567088 label_list_original as input x: [5, 2, 3, 4, 6] ;input_y_label: [[6 4 3 2 5 1]] prediction: [[6 4 3 2 5 1]]
# 1391 loss: 2.9124427 label_list_original as input x: [6, 4, 3, 5, 2] ;input_y_label: [[2 5 3 4 6 1]] prediction: [[2 5 3 4 6 1]]
# 1392 loss: 3.495214 label_list_original as input x: [2, 4, 5, 6, 3] ;input_y_label: [[3 6 5 4 2 1]] prediction: [[3 6 5 4 2 1]]
# 1393 loss: 3.222161 label_list_original as input x: [2, 6, 4, 5, 3] ;input_y_label: [[3 5 4 6 2 1]] prediction: [[3 5 4 6 2 1]]
# 1394 loss: 3.1071987 label_list_original as input x: [3, 4, 5, 6, 2] ;input_y_label: [[2 6 5 4 3 1]] prediction: [[2 6 5 4 3 1]]
# 1395 loss: 3.4506495 label_list_original as input x: [3, 2, 4, 6, 5] ;input_y_label: [[5 6 4 2 3 1]] prediction: [[5 6 4 2 3 1]]
# 1396 loss: 3.148326 label_list_original as input x: [3, 5, 4, 2, 6] ;input_y_label: [[6 2 4 5 3 1]] prediction: [[6 2 4 5 3 1]]
# 1397 loss: 3.1059756 label_list_original as input x: [2, 3, 6, 5, 4] ;input_y_label: [[4 5 6 3 2 1]] prediction: [[4 5 6 3 2 1]]
# 1398 loss: 3.2180376 label_list_original as input x: [6, 2, 5, 4, 3] ;input_y_label: [[3 4 5 2 6 1]] prediction: [[3 4 5 2 6 1]]
# 1399 loss: 2.9136224 label_list_original as input x: [4, 6, 5, 3, 2] ;input_y_label: [[2 3 5 6 4 1]] prediction: [[2 3 5 6 4 1]]
# 1400 loss: 3.3626761 label_list_original as input x: [5, 3, 4, 6, 2] ;input_y_label: [[2 6 4 3 5 1]] prediction: [[2 6 4 3 5 1]]
# 1401 loss: 3.385363 label_list_original as input x: [2, 4, 3, 5, 6] ;input_y_label: [[6 5 3 4 2 1]] prediction: [[6 5 3 4 2 1]]
# 1402 loss: 2.906804 label_list_original as input x: [5, 3, 2, 4, 6] ;input_y_label: [[6 4 2 3 5 1]] prediction: [[6 4 2 3 5 1]]
# 1403 loss: 3.1118994 label_list_original as input x: [6, 3, 2, 5, 4] ;input_y_label: [[4 5 2 3 6 1]] prediction: [[4 5 2 3 6 1]]
# 1404 loss: 3.2221568 label_list_original as input x: [5, 3, 4, 6, 2] ;input_y_label: [[2 6 4 3 5 1]] prediction: [[2 6 4 3 5 1]]
# 1405 loss: 3.057923 label_list_original as input x: [4, 2, 5, 3, 6] ;input_y_label: [[6 3 5 2 4 1]] prediction: [[6 3 5 2 4 1]]
# 1406 loss: 3.3049269 label_list_original as input x: [6, 4, 2, 5, 3] ;input_y_label: [[3 5 2 4 6 1]] prediction: [[3 5 2 4 6 1]]
# 1407 loss: 3.4888809 label_list_original as input x: [6, 3, 5, 2, 4] ;input_y_label: [[4 2 5 3 6 1]] prediction: [[4 2 5 3 6 1]]
# 1408 loss: 3.0756862 label_list_original as input x: [6, 2, 5, 4, 3] ;input_y_label: [[3 4 5 2 6 1]] prediction: [[3 4 5 2 6 1]]
# 1409 loss: 3.1925483 label_list_original as input x: [4, 3, 2, 5, 6] ;input_y_label: [[6 5 2 3 4 1]] prediction: [[6 5 2 3 4 1]]
# 1410 loss: 3.2101445 label_list_original as input x: [4, 2, 3, 5, 6] ;input_y_label: [[6 5 3 2 4 1]] prediction: [[6 5 3 2 4 1]]
# 1411 loss: 3.264902 label_list_original as input x: [6, 5, 2, 3, 4] ;input_y_label: [[4 3 2 5 6 1]] prediction: [[4 3 2 5 6 1]]
# 1412 loss: 3.124485 label_list_original as input x: [6, 3, 4, 2, 5] ;input_y_label: [[5 2 4 3 6 1]] prediction: [[5 2 4 3 6 1]]
# 1413 loss: 2.9499183 label_list_original as input x: [4, 2, 6, 5, 3] ;input_y_label: [[3 5 6 2 4 1]] prediction: [[3 5 6 2 4 1]]
# 1414 loss: 2.9860272 label_list_original as input x: [4, 2, 5, 6, 3] ;input_y_label: [[3 6 5 2 4 1]] prediction: [[3 6 5 2 4 1]]
# 1415 loss: 3.1669226 label_list_original as input x: [5, 3, 4, 6, 2] ;input_y_label: [[2 6 4 3 5 1]] prediction: [[2 6 4 3 5 1]]
# 1416 loss: 3.272561 label_list_original as input x: [5, 6, 3, 4, 2] ;input_y_label: [[2 4 3 6 5 1]] prediction: [[2 4 3 6 5 1]]
# 1417 loss: 2.9991589 label_list_original as input x: [5, 4, 6, 2, 3] ;input_y_label: [[3 2 6 4 5 1]] prediction: [[3 2 6 4 5 1]]
# 1418 loss: 3.2087045 label_list_original as input x: [2, 3, 4, 5, 6] ;input_y_label: [[6 5 4 3 2 1]] prediction: [[6 5 4 3 2 1]]
# 1419 loss: 3.3058574 label_list_original as input x: [2, 6, 3, 5, 4] ;input_y_label: [[4 5 3 6 2 1]] prediction: [[4 5 3 6 2 1]]
# 1420 loss: 2.8485425 label_list_original as input x: [5, 2, 6, 4, 3] ;input_y_label: [[3 4 6 2 5 1]] prediction: [[3 4 6 2 5 1]]
# 1421 loss: 3.0460339 label_list_original as input x: [2, 3, 6, 5, 4] ;input_y_label: [[4 5 6 3 2 1]] prediction: [[4 5 6 3 2 1]]
# 1422 loss: 3.4895048 label_list_original as input x: [4, 3, 2, 6, 5] ;input_y_label: [[5 6 2 3 4 1]] prediction: [[6 6 2 3 4 1]]
# 1423 loss: 3.3970208 label_list_original as input x: [6, 2, 5, 3, 4] ;input_y_label: [[4 3 5 2 6 1]] prediction: [[4 3 5 2 6 1]]
# 1424 loss: 2.7865279 label_list_original as input x: [4, 3, 5, 6, 2] ;input_y_label: [[2 6 5 3 4 1]] prediction: [[2 6 5 3 4 1]]
# 1425 loss: 2.9869943 label_list_original as input x: [6, 2, 5, 4, 3] ;input_y_label: [[3 4 5 2 6 1]] prediction: [[3 4 5 2 6 1]]
# 1426 loss: 3.186556 label_list_original as input x: [2, 4, 5, 6, 3] ;input_y_label: [[3 6 5 4 2 1]] prediction: [[3 6 5 4 2 1]]
# 1427 loss: 3.0799322 label_list_original as input x: [3, 5, 2, 6, 4] ;input_y_label: [[4 6 2 5 3 1]] prediction: [[6 6 2 5 3 1]]
# 1428 loss: 3.3178725 label_list_original as input x: [2, 3, 4, 6, 5] ;input_y_label: [[5 6 4 3 2 1]] prediction: [[5 6 4 3 2 1]]
# 1429 loss: 3.43713 label_list_original as input x: [6, 4, 2, 3, 5] ;input_y_label: [[5 3 2 4 6 1]] prediction: [[5 3 2 4 6 1]]
# 1430 loss: 3.1422348 label_list_original as input x: [2, 4, 5, 6, 3] ;input_y_label: [[3 6 5 4 2 1]] prediction: [[3 6 5 4 2 1]]
# 1431 loss: 2.9028492 label_list_original as input x: [6, 2, 5, 4, 3] ;input_y_label: [[3 4 5 2 6 1]] prediction: [[3 4 5 2 6 1]]
# 1432 loss: 2.8113241 label_list_original as input x: [3, 2, 6, 5, 4] ;input_y_label: [[4 5 6 2 3 1]] prediction: [[4 5 6 2 3 1]]
# 1433 loss: 2.9534898 label_list_original as input x: [5, 6, 2, 3, 4] ;input_y_label: [[4 3 2 6 5 1]] prediction: [[4 3 2 6 5 1]]
# 1434 loss: 3.135308 label_list_original as input x: [4, 2, 3, 6, 5] ;input_y_label: [[5 6 3 2 4 1]] prediction: [[5 6 3 2 4 1]]
# 1435 loss: 3.2062454 label_list_original as input x: [6, 4, 3, 2, 5] ;input_y_label: [[5 2 3 4 6 1]] prediction: [[5 2 3 4 6 1]]
# 1436 loss: 2.8051038 label_list_original as input x: [4, 5, 3, 6, 2] ;input_y_label: [[2 6 3 5 4 1]] prediction: [[2 6 3 5 4 1]]
# 1437 loss: 2.8640308 label_list_original as input x: [5, 3, 6, 4, 2] ;input_y_label: [[2 4 6 3 5 1]] prediction: [[2 4 6 3 5 1]]
# 1438 loss: 2.8469336 label_list_original as input x: [3, 2, 5, 6, 4] ;input_y_label: [[4 6 5 2 3 1]] prediction: [[4 6 5 2 3 1]]
# 1439 loss: 2.9648786 label_list_original as input x: [4, 3, 5, 2, 6] ;input_y_label: [[6 2 5 3 4 1]] prediction: [[6 2 5 3 4 1]]
# 1440 loss: 3.232955 label_list_original as input x: [2, 4, 5, 3, 6] ;input_y_label: [[6 3 5 4 2 1]] prediction: [[6 3 5 4 2 1]]
# 1441 loss: 3.0680118 label_list_original as input x: [2, 6, 3, 4, 5] ;input_y_label: [[5 4 3 6 2 1]] prediction: [[5 4 3 6 2 1]]
# 1442 loss: 2.7762167 label_list_original as input x: [4, 6, 5, 2, 3] ;input_y_label: [[3 2 5 6 4 1]] prediction: [[3 2 5 6 4 1]]
# 1443 loss: 3.195342 label_list_original as input x: [3, 6, 4, 2, 5] ;input_y_label: [[5 2 4 6 3 1]] prediction: [[5 2 4 6 3 1]]
# 1444 loss: 3.0358903 label_list_original as input x: [5, 4, 3, 2, 6] ;input_y_label: [[6 2 3 4 5 1]] prediction: [[6 2 3 4 5 1]]
# 1445 loss: 2.9002345 label_list_original as input x: [4, 2, 5, 3, 6] ;input_y_label: [[6 3 5 2 4 1]] prediction: [[6 3 5 2 4 1]]
# 1446 loss: 3.1212072 label_list_original as input x: [2, 4, 3, 6, 5] ;input_y_label: [[5 6 3 4 2 1]] prediction: [[5 6 3 4 2 1]]
# 1447 loss: 2.9278429 label_list_original as input x: [6, 2, 3, 4, 5] ;input_y_label: [[5 4 3 2 6 1]] prediction: [[5 4 3 2 6 1]]
# 1448 loss: 2.7955885 label_list_original as input x: [5, 4, 3, 6, 2] ;input_y_label: [[2 6 3 4 5 1]] prediction: [[2 6 3 4 5 1]]
# 1449 loss: 2.9329615 label_list_original as input x: [6, 2, 4, 3, 5] ;input_y_label: [[5 3 4 2 6 1]] prediction: [[5 3 4 2 6 1]]
# 1450 loss: 2.8239775 label_list_original as input x: [5, 6, 2, 3, 4] ;input_y_label: [[4 3 2 6 5 1]] prediction: [[4 3 2 6 5 1]]
# 1451 loss: 2.761683 label_list_original as input x: [5, 4, 3, 6, 2] ;input_y_label: [[2 6 3 4 5 1]] prediction: [[2 6 3 4 5 1]]
# 1452 loss: 3.2588978 label_list_original as input x: [3, 4, 2, 6, 5] ;input_y_label: [[5 6 2 4 3 1]] prediction: [[5 6 2 4 3 1]]
# 1453 loss: 2.9475768 label_list_original as input x: [2, 3, 6, 5, 4] ;input_y_label: [[4 5 6 3 2 1]] prediction: [[4 5 6 3 2 1]]
# 1454 loss: 3.0562081 label_list_original as input x: [2, 4, 5, 3, 6] ;input_y_label: [[6 3 5 4 2 1]] prediction: [[6 3 5 4 2 1]]
# 1455 loss: 2.8369439 label_list_original as input x: [2, 4, 6, 5, 3] ;input_y_label: [[3 5 6 4 2 1]] prediction: [[3 5 6 4 2 1]]
# 1456 loss: 3.3575208 label_list_original as input x: [2, 5, 4, 6, 3] ;input_y_label: [[3 6 4 5 2 1]] prediction: [[3 6 5 5 2 1]]
# 1457 loss: 2.973106 label_list_original as input x: [5, 2, 4, 6, 3] ;input_y_label: [[3 6 4 2 5 1]] prediction: [[3 6 4 2 5 1]]
# 1458 loss: 2.6752348 label_list_original as input x: [3, 2, 5, 4, 6] ;input_y_label: [[6 4 5 2 3 1]] prediction: [[6 4 5 2 3 1]]
# 1459 loss: 3.318405 label_list_original as input x: [3, 4, 6, 2, 5] ;input_y_label: [[5 2 6 4 3 1]] prediction: [[2 2 6 4 3 1]]
# 1460 loss: 3.0199556 label_list_original as input x: [2, 3, 5, 4, 6] ;input_y_label: [[6 4 5 3 2 1]] prediction: [[6 4 5 3 2 1]]
# 1461 loss: 3.0009172 label_list_original as input x: [2, 4, 3, 5, 6] ;input_y_label: [[6 5 3 4 2 1]] prediction: [[6 5 3 4 2 1]]
# 1462 loss: 3.4077659 label_list_original as input x: [6, 5, 3, 4, 2] ;input_y_label: [[2 4 3 5 6 1]] prediction: [[2 4 3 5 6 1]]
# 1463 loss: 2.9460146 label_list_original as input x: [2, 4, 5, 6, 3] ;input_y_label: [[3 6 5 4 2 1]] prediction: [[3 6 5 4 2 1]]
# 1464 loss: 2.792003 label_list_original as input x: [6, 4, 3, 5, 2] ;input_y_label: [[2 5 3 4 6 1]] prediction: [[2 5 3 4 6 1]]
# 1465 loss: 3.0270114 label_list_original as input x: [4, 2, 3, 5, 6] ;input_y_label: [[6 5 3 2 4 1]] prediction: [[6 5 3 2 4 1]]
# 1466 loss: 3.0246906 label_list_original as input x: [4, 5, 6, 3, 2] ;input_y_label: [[2 3 6 5 4 1]] prediction: [[2 3 6 5 4 1]]
# 1467 loss: 2.9944983 label_list_original as input x: [3, 6, 5, 2, 4] ;input_y_label: [[4 2 5 6 3 1]] prediction: [[4 2 5 6 3 1]]
# 1468 loss: 2.993749 label_list_original as input x: [5, 4, 6, 2, 3] ;input_y_label: [[3 2 6 4 5 1]] prediction: [[3 2 6 4 5 1]]
# 1469 loss: 2.8167925 label_list_original as input x: [3, 4, 2, 5, 6] ;input_y_label: [[6 5 2 4 3 1]] prediction: [[6 5 2 4 3 1]]
# 1470 loss: 3.293723 label_list_original as input x: [6, 5, 4, 3, 2] ;input_y_label: [[2 3 4 5 6 1]] prediction: [[2 3 4 5 6 1]]
# 1471 loss: 2.9416802 label_list_original as input x: [3, 6, 4, 2, 5] ;input_y_label: [[5 2 4 6 3 1]] prediction: [[5 2 4 6 3 1]]
# 1472 loss: 3.1155834 label_list_original as input x: [2, 5, 6, 4, 3] ;input_y_label: [[3 4 6 5 2 1]] prediction: [[3 4 6 5 2 1]]
# 1473 loss: 2.9700353 label_list_original as input x: [5, 6, 4, 3, 2] ;input_y_label: [[2 3 4 6 5 1]] prediction: [[2 3 4 6 5 1]]
# 1474 loss: 2.8524575 label_list_original as input x: [5, 3, 4, 2, 6] ;input_y_label: [[6 2 4 3 5 1]] prediction: [[6 2 4 3 5 1]]
# 1475 loss: 2.921835 label_list_original as input x: [5, 6, 3, 2, 4] ;input_y_label: [[4 2 3 6 5 1]] prediction: [[4 2 3 6 5 1]]
# 1476 loss: 3.5234509 label_list_original as input x: [2, 5, 3, 6, 4] ;input_y_label: [[4 6 3 5 2 1]] prediction: [[6 6 3 5 2 1]]
# 1477 loss: 2.7573047 label_list_original as input x: [5, 4, 6, 3, 2] ;input_y_label: [[2 3 6 4 5 1]] prediction: [[2 3 6 4 5 1]]
# 1478 loss: 2.859561 label_list_original as input x: [5, 3, 2, 6, 4] ;input_y_label: [[4 6 2 3 5 1]] prediction: [[4 6 2 3 5 1]]
# 1479 loss: 3.0797348 label_list_original as input x: [6, 5, 4, 3, 2] ;input_y_label: [[2 3 4 5 6 1]] prediction: [[2 3 4 5 6 1]]
# 1480 loss: 2.8293114 label_list_original as input x: [3, 6, 5, 2, 4] ;input_y_label: [[4 2 5 6 3 1]] prediction: [[4 2 5 6 3 1]]
# 1481 loss: 2.785152 label_list_original as input x: [4, 5, 3, 2, 6] ;input_y_label: [[6 2 3 5 4 1]] prediction: [[6 2 3 5 4 1]]
# 1482 loss: 2.7219026 label_list_original as input x: [5, 4, 3, 6, 2] ;input_y_label: [[2 6 3 4 5 1]] prediction: [[2 6 3 4 5 1]]
# 1483 loss: 3.6437962 label_list_original as input x: [4, 3, 6, 2, 5] ;input_y_label: [[5 2 6 3 4 1]] prediction: [[2 2 6 3 4 1]]
# 1484 loss: 3.052473 label_list_original as input x: [2, 6, 3, 4, 5] ;input_y_label: [[5 4 3 6 2 1]] prediction: [[5 4 3 6 2 1]]
# 1485 loss: 2.9088457 label_list_original as input x: [2, 6, 4, 3, 5] ;input_y_label: [[5 3 4 6 2 1]] prediction: [[5 3 4 6 2 1]]
# 1486 loss: 2.9302812 label_list_original as input x: [3, 4, 2, 5, 6] ;input_y_label: [[6 5 2 4 3 1]] prediction: [[6 5 2 4 3 1]]
# 1487 loss: 2.6905248 label_list_original as input x: [4, 5, 2, 3, 6] ;input_y_label: [[6 3 2 5 4 1]] prediction: [[6 3 2 5 4 1]]
# 1488 loss: 3.03006 label_list_original as input x: [3, 2, 6, 4, 5] ;input_y_label: [[5 4 6 2 3 1]] prediction: [[4 4 6 2 3 1]]
# 1489 loss: 2.9695601 label_list_original as input x: [6, 4, 3, 2, 5] ;input_y_label: [[5 2 3 4 6 1]] prediction: [[5 2 3 4 6 1]]
# 1490 loss: 2.9112005 label_list_original as input x: [5, 3, 4, 6, 2] ;input_y_label: [[2 6 4 3 5 1]] prediction: [[2 6 4 3 5 1]]
# 1491 loss: 2.6982064 label_list_original as input x: [4, 2, 5, 3, 6] ;input_y_label: [[6 3 5 2 4 1]] prediction: [[6 3 5 2 4 1]]
# 1492 loss: 2.7080593 label_list_original as input x: [5, 6, 3, 2, 4] ;input_y_label: [[4 2 3 6 5 1]] prediction: [[4 2 3 6 5 1]]
# 1493 loss: 2.6324208 label_list_original as input x: [5, 3, 2, 4, 6] ;input_y_label: [[6 4 2 3 5 1]] prediction: [[6 4 2 3 5 1]]
# 1494 loss: 3.108892 label_list_original as input x: [6, 5, 3, 2, 4] ;input_y_label: [[4 2 3 5 6 1]] prediction: [[4 2 3 5 6 1]]
# 1495 loss: 2.577203 label_list_original as input x: [3, 4, 6, 5, 2] ;input_y_label: [[2 5 6 4 3 1]] prediction: [[2 5 6 4 3 1]]
# 1496 loss: 3.438611 label_list_original as input x: [6, 3, 5, 4, 2] ;input_y_label: [[2 4 5 3 6 1]] prediction: [[2 5 5 3 6 1]]
# 1497 loss: 2.7991323 label_list_original as input x: [5, 3, 4, 2, 6] ;input_y_label: [[6 2 4 3 5 1]] prediction: [[6 2 4 3 5 1]]
# 1498 loss: 2.9752874 label_list_original as input x: [3, 4, 2, 6, 5] ;input_y_label: [[5 6 2 4 3 1]] prediction: [[5 6 2 4 3 1]]
# 1499 loss: 2.9513516 label_list_original as input x: [6, 2, 5, 4, 3] ;input_y_label: [[3 4 5 2 6 1]] prediction: [[3 4 5 2 6 1]]
